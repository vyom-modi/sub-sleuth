# %% [markdown]
# # **Setting up the environment**

# %%
import os
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

# %%
# !pip install -U sentence-transformers
# !pip install tqdm
# !pip install beautifulsoup4
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (4.38.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (2.1.2+cpu)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (0.21.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (9.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.3.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (21.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.15.1->sentence-transformers) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 4.4 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.7.0
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4) (2.5)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.2.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk) (1.16.0)

# %%
# !pip install torch sentence-transformers[gpu]
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2+cpu)
# Requirement already satisfied: sentence-transformers[gpu] in /opt/conda/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.0)
# WARNING: sentence-transformers 2.7.0 does not provide the extra 'gpu'
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers[gpu]) (4.38.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence-transformers[gpu]) (4.66.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers[gpu]) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence-transformers[gpu]) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers[gpu]) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers[gpu]) (0.21.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence-transformers[gpu]) (9.5.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers[gpu]) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers[gpu]) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers[gpu]) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers[gpu]) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers[gpu]) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers[gpu]) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers[gpu]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers[gpu]) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.15.1->sentence-transformers[gpu]) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers[gpu]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers[gpu]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers[gpu]) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers[gpu]) (2024.2.2)

# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in /opt/conda/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: build>=1.0.3 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: requests>=2.28 in /opt/conda/lib/python3.10/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /opt/conda/lib/python3.10/site-packages (from chromadb) (2.5.3)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.108.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.25.0)
# Requirement already satisfied: numpy>=1.22.5 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (4.9.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.17.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.43b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /opt/conda/lib/python3.10/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.10/site-packages (from chromadb) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.60.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from chromadb) (4.1.2)
# Requirement already satisfied: typer>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (29.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/conda/lib/python3.10/site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /opt/conda/lib/python3.10/site-packages (from chromadb) (3.10.1)
# Requirement already satisfied: packaging>=19.1 in /opt/conda/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (21.3)
# Requirement already satisfied: pyproject_hooks in /opt/conda/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: starlette<0.33.0,>=0.29.0 in /opt/conda/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb) (0.32.0.post1)
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.26.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/conda/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/conda/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /opt/conda/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.18)
# Requirement already satisfied: coloredlogs in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.11.0)
# Requirement already satisfied: backoff<3.0.0,>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (2.2.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.62.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.22.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-proto==1.22.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.43b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.43b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.43b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.43b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.43b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.43b0)
# Requirement already satisfied: opentelemetry-util-http==0.43b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.43b0)
# Requirement already satisfied: setuptools>=16.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (69.0.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.6)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /opt/conda/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb) (0.21.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.3.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=19.1->build>=1.0.3->chromadb) (3.1.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from starlette<0.33.0,>=0.29.0->fastapi>=0.95.2->chromadb) (4.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/conda/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.33.0,>=0.29.0->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.33.0,>=0.29.0->fastapi>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)

# %% [markdown]
# # **Part 1: Ingesting Documents**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/subtitle_multi-qa-minilm-l6-cos-v1_bert_embeddings/pytorch/1/1/subtitle_multi-qa-MiniLM-L6-cos-v1_bert_embeddings_pytorch.pt
# /kaggle/input/opensubtitles-sql-database/data/eng_subtitles_database.db
# /kaggle/input/opensubtitles-sql-database/data/README.txt
# /kaggle/input/opensubtitles-preprocessed-with-bert-embeddings/preprocessed_subtitles_30_with_chunks_embeddings.csv
# /kaggle/input/opensubtitles-preprocessed-data/opensubtitles_data_preprocessed.csv
# /kaggle/input/opensubtitles-preprocessed-with-chunks-30-percent/preprocessed_subtitles_30_with_chunks.csv

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/lib/kaggle/gcp.py
# /kaggle/input/opensubtitles-preprocessed-data/opensubtitles_data_preprocessed.csv
# /kaggle/input/opensubtitles-preprocessed-with-chunks-30-percent/preprocessed_subtitles_30_with_chunks.csv
# /kaggle/input/opensubtitles-sql-database/data/eng_subtitles_database.db
# /kaggle/input/opensubtitles-sql-database/data/README.txt
# /kaggle/input/opensubtitles-preprocessed-with-bert-embeddings/preprocessed_subtitles_30_with_chunks_embeddings.csv

# %%
os.path.isfile("/kaggle/working/preprocessed_subtitles_30.csv")
# Out:
# False

# %% [markdown]
# ### **Decoding and Reading the given data.**

# %%
import sqlite3
import zipfile
import io

def read_and_decode_database(file_path):
    # Connect to the SQLite database
    connection = sqlite3.connect(file_path)
    # Read the database into a DataFrame
    data = pd.read_sql_query("SELECT * FROM zipfiles", connection)
    # Close the connection
    connection.close()
    
    # Initialize count variable
    count = 0
    
    # Function to decode binary data from zip files
    def decode_binary_data(binary_data):
        nonlocal count
        count += 1
        try:
            with io.BytesIO(binary_data) as byte_stream:
                with zipfile.ZipFile(byte_stream, 'r') as zip_file:
                    file_name = zip_file.namelist()[0]
                    subtitle_content = zip_file.read(file_name)
                    return subtitle_content.decode('latin-1')
        except Exception as e:
            print(f"Error: {e}")
            return None
    
    # Decode each binary data entry in the DataFrame
    data['file_content'] = data['content'].apply(decode_binary_data)
    
    return data, count

# # Apply the function to the content column
file_path = '/kaggle/input/opensubtitles-sql-database/data/eng_subtitles_database.db'
df, df_count = read_and_decode_database(file_path)

# Display the first few rows of the DataFrame with decoded content
df.head()
# Out:
#        num                                               name  \
# 0  9180533                         the.message.(1976).eng.1cd
# 1  9180583  here.comes.the.grump.s01.e09.joltin.jack.in.bo...
# 2  9180592    yumis.cells.s02.e13.episode.2.13.(2022).eng.1cd
# 3  9180594    yumis.cells.s02.e14.episode.2.14.(2022).eng.1cd
# 4  9180600                              broker.(2022).eng.1cd
#
#                                              content  \
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x1c\xa9\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x17\xb9\x...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00L\xb9\x99V...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00U\xa9\x99V...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x001\xa9\x99V...
#
#                                         file_content
# 0  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 1  1\r\n00:00:29,359 --> 00:00:32,048\r\nAh! Ther...
# 2  1\r\n00:00:53,200 --> 00:00:56,030\r\n<i>Yumi'...
# 3  1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch an...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...

# %% [markdown]
# **Selecting the 30% of the given data randomly**

# %%
# Selecting 30% of the data randomly
df_sampled = df.sample(frac=0.3, random_state=42)

# %%
# Display the first few rows of the sampled DataFrame
df_sampled.head()
# Out:
#            num                                               name  \
# 17262  9251120                     maybe.this.time.(2014).eng.1cd
# 7294   9211589  down.the.shore.s01.e10.and.justice.for.all.(19...
# 47707  9380845  uncontrollably.fond.s01.e07.heartache.(2016).e...
# 29914  9301436  screen.two.s13.e04.the.precious.blood.(1996).e...
# 54266  9408707                          battlebots.(2015).eng.1cd
#
#                                                  content  \
# 17262  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x89\x9a\x...
# 7294   b'PK\x03\x04\x14\x00\x00\x00\x08\x007\x8f\x99V...
# 47707  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x8f\x19\x...
# 29914  b'PK\x03\x04\x14\x00\x00\x00\x08\x00[\xaa\x99V...
# 54266  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf4<\x9aV...
#
#                                             file_content
# 17262  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...
# 7294   1\r\n00:00:09,275 --> 00:00:11,876\r\n¶ Oh, I ...
# 47707  1\r\n00:00:07,140 --> 00:00:14,220\r\n<i>Timin...
# 29914  1\r\n00:00:06,133 --> 00:00:08,900\r\n[etherea...
# 54266  ï»¿1\r\n00:00:01,480 --> 00:00:03,570\r\n[Chri...

# %% [markdown]
# ## **Applying the appropriate cleaning steps on subtitle documents**

# %%
import re
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Ensure you have the necessary NLTK data downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def clean_text(text):
    # Remove timestamps
    text = re.sub(r'\d+:\d+:\d+,\d+ --> \d+:\d+:\d+,\d+', '', text)
    # Remove line numbers and HTML tags
    text = re.sub(r'\b\d+\b', '', text)
    text = BeautifulSoup(text, "html.parser").get_text(separator=" ")
    # Remove special characters, punctuation, and symbols
    text = re.sub(r'[^\w\s]', '', text)
    # Remove extra whitespace and convert to lowercase
    text = re.sub(r'\s+', ' ', text).lower()
    # Tokenize the text and remove stopwords
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    # Reconstruct the cleaned text
    cleaned_text = ' '.join(tokens)
    return cleaned_text

print('\n\nApplying `clean_text` function on the Data')
df_sampled['cleaned_content'] = df_sampled['file_content'].apply(clean_text)

# %%
# Display the first few rows of the DataFrame with cleaned content
df_sampled[['name', 'cleaned_content']].head()
# Out:
#                                                 name  \
# 0                     maybe.this.time.(2014).eng.1cd
# 1  down.the.shore.s01.e10.and.justice.for.all.(19...
# 2  uncontrollably.fond.s01.e07.heartache.(2016).e...
# 3  screen.two.s13.e04.the.precious.blood.(1996).e...
# 4                          battlebots.(2015).eng.1cd
#
#                                      cleaned_content
# 0  ï watch video online opensubtitles free browse...
# 1  oh know getting late dont wan na go home im hu...
# 2  timing subtitles uncontrollable lovebirds team...
# 3  ethereal music apiopensubtitlesorg deprecated ...
# 4  ï chris oh minibots yelling oh leave little bo...

# %%
df_sampled[['name', 'cleaned_content']].to_csv('preprocessed_subtitles_30.csv')

# %% [markdown]
# The `optimized_document_chunker` function efficiently breaks down a large document into smaller, overlapping chunks. It is particularly useful for natural language processing tasks. Here are the key details:
#
# - **Arguments**:
#   - `document` (str): The input subtitle document to be chunked.
#   - `max_tokens_per_chunk` (int, optional): Maximum number of tokens allowed per chunk (default is 500).
#   - `overlap_tokens` (int, optional): Number of tokens to overlap between adjacent chunks (default is 50).
#
# - **Returns**:
#   - A list of chunked segments from the original document.
#
# This function tokenizes the input document, calculates the necessary number of chunks, and creates these chunks efficiently. It's designed to handle large texts while ensuring overlapping segments for context preservation. 📝🚀

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

def optimized_document_chunker(document, max_tokens_per_chunk=500, overlap_tokens=50):
    """
    Chunk a large document into smaller, overlapping chunks efficiently.
    
    Args:
    - document (str): The subtitle document to be chunked.
    - max_tokens_per_chunk (int): Maximum number of tokens allowed per chunk.
    - overlap_tokens (int): Number of tokens to overlap between adjacent chunks.
    
    Returns:
    - List[str]: List of chunked segments from the document.
    """
    # Tokenize the document into individual words or subwords
    tokens = [word for word in document.split() if word not in ENGLISH_STOP_WORDS]
    
    # Calculate the number of chunks needed
    num_chunks = (len(tokens) - overlap_tokens) // (max_tokens_per_chunk - overlap_tokens) + 1
    
    # Create chunks using list comprehension for better performance
    chunks = [
        ' '.join(tokens[i:i + max_tokens_per_chunk])
        for i in range(0, len(tokens), max_tokens_per_chunk - overlap_tokens)
        if i + max_tokens_per_chunk <= len(tokens) or i == (num_chunks - 1) * (max_tokens_per_chunk - overlap_tokens)
    ]
    
    return chunks

# %%
# Apply the document chunker to the cleaned content column
df_sampled['chunks'] = df_sampled['cleaned_content'].apply(optimized_document_chunker)

# %%
df_sampled['chunks']
# Out:
# 0        ['ï watch video online opensubtitles free brow...
# 1        ['oh know getting late dont wan na home im hur...
# 2        ['timing subtitles uncontrollable lovebirds te...
# 3        ['ethereal music apiopensubtitlesorg deprecate...
# 4        ['ï chris oh minibots yelling oh leave little ...
#                                ...
# 24744    ['ïscript info title default file scripttype v...
# 24745    ['ï come dont know tape helena girls called ca...
# 24746    ['ï previously heroes tell virus stop primatec...
# 24747    ['ï hot cleveland recorded live studio audienc...
# 24748    ['ï apiopensubtitlesorg deprecated implement r...
# Name: chunks, Length: 24749, dtype: object

# %%
df_sampled[['name', 'cleaned_content', 'chunks']].to_csv('preprocessed_subtitles_30_with_chunks.csv')

# %%
df_sampled = pd.read_csv("/kaggle/input/opensubtitles-preprocessed-with-chunks-30-percent/preprocessed_subtitles_30_with_chunks.csv")

# %% [markdown]
# ## **Experiment with the following to generate text vectors of subtitle documents**

# %% [markdown]
# ### Generating Text Embeddings with the **TfidfVectorizer** for the keyword-based search engine experimentation.

# %% [markdown]
# The **TF-IDF Vectorizer** is used to transform subtitle text data into TF-IDF vectors, which represent the importance of words in the context of the entire document collection. It helps improve interpretability by associating feature names with these vectors. 📊🔤

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

def tfidf_vectorize(subtitles):   
    vectorizer = TfidfVectorizer(stop_words='english')
    # Fit the vectorizer to the subtitles and transform the subtitles into TF-IDF vectors
    vectors = vectorizer.fit_transform(subtitles)
    # Return the TF-IDF vectors along with the feature names for better interpretability
    return vectors, vectorizer.get_feature_names_out()

subtitle_tfidf_vectors, subtitle_feature_names1 = tfidf_vectorize(df_sampled['chunks'])

# %%
import pickle

with open('subtitle_chunks_tfidf_vectors_final.pkl', 'wb') as f:
    pickle.dump(subtitle_tfidf_vectors, f)

with open('subtitle_chunks_feature_names_final.pkl', 'wb') as f:
    pickle.dump(subtitle_feature_names1, f)

# %%
import os
import pickle

# Check if the file exists and is not empty
if os.path.exists('subtitle_chunks_tfidf_vectors_final.pkl') and os.path.getsize('subtitle_chunks_tfidf_vectors_final.pkl') > 0:
    with open('subtitle_chunks_tfidf_vectors_final.pkl', 'rb') as file:
        try:
            subtitle_tfidf_vectors = pickle.load(file)
        except EOFError:
            # Handle the exception if the file is not properly pickled
            subtitle_tfidf_vectors = None
            print("The file is not properly pickled or is empty.")
else:
    print("The file does not exist or is empty.")

# Now you can use subtitle_tfidf_vectors as a normal variable, if it was loaded successfully
if subtitle_tfidf_vectors is not None:
    print(subtitle_tfidf_vectors)
# Out:
#   (0, 542551)	0.0016152756544135388
#   (0, 81167)	0.001422704219523802
#   (0, 586605)	0.001657147619625029
#   (0, 611386)	0.008751832265513317
#   (0, 541251)	0.001648835706289278
#   (0, 473399)	0.0015370077694319094
#   (0, 337807)	0.004856223054457998
#   (0, 311249)	0.0035196455045136887
#   (0, 527828)	0.007282381687701824
#   (0, 217070)	0.00839746094110244
#   (0, 524858)	0.004680375517401724
#   (0, 524897)	0.012391117023521648
#   (0, 246701)	0.0012215867693711154
#   (0, 444777)	0.003510333123604347
#   (0, 396304)	0.0056135710305065005
#   (0, 260012)	0.0015710853277995421
#   (0, 262333)	0.004495967706003902
#   (0, 425378)	0.01794132166533833
#   (0, 282949)	0.00841139141309038
#   (0, 235866)	0.004303203654556054
#   (0, 524860)	0.004164232691588318
#   (0, 23973)	0.0030209681628947365
#   (0, 465834)	0.007180210155673248
#   (0, 189145)	0.0034985086227181327
#   (0, 87263)	0.00489362970385651
#   :	:
#   (24748, 387123)	0.0380810860048123
#   (24748, 595429)	0.005765402356754568
#   (24748, 211124)	0.00514655134593789
#   (24748, 407029)	0.023917219353498484
#   (24748, 246633)	0.020595449830053198
#   (24748, 561052)	0.007135317001501641
#   (24748, 265343)	0.07541052117001305
#   (24748, 273216)	0.028095131685706834
#   (24748, 192376)	0.19431512903293524
#   (24748, 312566)	0.006756838336683874
#   (24748, 280861)	0.12095189737540596
#   (24748, 87863)	0.08443840018526409
#   (24748, 538141)	0.01502211206103962
#   (24748, 470139)	0.0056656784871154066
#   (24748, 624040)	0.06603039938920026
#   (24748, 431746)	0.10150255851148735
#   (24748, 327870)	0.021889906588075447
#   (24748, 76673)	0.014916773820231984
#   (24748, 246123)	0.08191945052658482
#   (24748, 328439)	0.09945920448609352
#   (24748, 186766)	0.009897478802671554
#   (24748, 504911)	0.005040868708367748
#   (24748, 94289)	0.01726613074522178
#   (24748, 233177)	0.004730714413650528
#   (24748, 596785)	0.013210605374644989

# %% [markdown]
# ### Generating Text Embeddings with the **multi-qa-MiniLM-L6-cos-v1** model

# %% [markdown]
# The **multi-qa-MiniLM-L6-cos-v1** model is a **sentence-transformers** model designed for **semantic search**. It maps sentences and paragraphs to a 384-dimensional dense vector space and has been trained on 215 million (question, answer) pairs from diverse sources¹[1].

# %%
import torch
import sentence_transformers
from sentence_transformers import SentenceTransformer, util
from tqdm import tqdm

# Initialize the model outside the function to avoid loading it multiple times
model = SentenceTransformer('sentence-transformers/multi-qa-MiniLM-L6-cos-v1') # bert-base-nli-mean-tokens and sentence-transformers/all-MiniLM-L6-v2

def generate_sentence_embeddings(subtitles):
    # Check if CUDA is available and set the device accordingly
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    # # Join each list of strings into a single string per subtitle entry
    # subtitles_series = subtitles_series.apply(lambda chunks: ' '.join(chunks) if isinstance(chunks, list) else chunks)
    
    # # Convert the pandas Series to a list of strings
    # subtitles_list = subtitles_series.tolist()
#     subtitles = [' '.join(chunk) if isinstance(chunk, list) else chunk for chunk in subtitles]
    
    # Encode the subtitles to get the embeddings
    embeddings = model.encode(subtitles, show_progress_bar=True, convert_to_tensor=True)
    
    # Move embeddings to CPU and convert to numpy array if they are not already
    if torch.cuda.is_available():
        embeddings = embeddings.cpu()
    
    embeddings_numpy = embeddings.numpy()
    return embeddings_numpy
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/11.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/383 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# **Applying the `generate_sentence_embeddings` function on the generated chunks from the data.**

# %%
# Encode the chunks using Sentence Transformers
# df_sampled['chunk_embeddings'] = df_sampled['chunks'].apply(encode_chunks)
subtitle_bert_embeddings = generate_sentence_embeddings(df_sampled['chunks'].tolist())
subtitle_bert_embeddings

# %% [markdown]
# **Saving the generated embeddings to numpy array and pytorch file**

# %%
# Assuming subtitle_bert_embeddings is a numpy array
np.save('subtitle_embeddings.npy', subtitle_bert_embeddings)

# %%
import torch

# Save the embeddings to a file
torch.save(subtitle_bert_embeddings, 'subtitle_embeddings.pt')

# %%
import torch

subtitle_embeddings_bert = torch.load('/kaggle/input/subtitle_multi-qa-minilm-l6-cos-v1_bert_embeddings/pytorch/1/1/subtitle_multi-qa-MiniLM-L6-cos-v1_bert_embeddings_pytorch.pt')

# %%
subtitle_embeddings_bert.shape
# Out:
# (24749, 384)

# %%
# # df_sampled['chunk_embeddings'] = subtitle_bert_embeddings.tolist()
# df_sampled[['name', 'cleaned_content', 'chunks', 'chunk_embeddings']].to_csv('preprocessed_subtitles_30_with_all-MiniLM-L6-v2_embeddings.csv')

# %% [markdown]
# ## **Storing the generated embeddings in a ChromaDB database.**

# %%
import pandas as pd
import numpy as np

df_sampled = pd.read_csv('/kaggle/input/opensubtitles-preprocessed-with-bert-embeddings/preprocessed_subtitles_30_with_chunks_embeddings.csv')

# %% [markdown]
# **The below code generates unique IDs and metadata for each document in a DataFrame. 📄🔑**

# %%
import uuid

ids = []
metadatas = []
for index, row in df_sampled.iterrows():
        ids.append(str(uuid.uuid4()))
        print({"name": row['name'], "chunk_index": index})
        metadatas.append({"name": row['name'], "index": index})
# Out:
# {'name': 'maybe.this.time.(2014).eng.1cd', 'chunk_index': 0}
# {'name': 'down.the.shore.s01.e10.and.justice.for.all.(1992).eng.1cd', 'chunk_index': 1}
# {'name': 'uncontrollably.fond.s01.e07.heartache.(2016).eng.1cd', 'chunk_index': 2}
# {'name': 'screen.two.s13.e04.the.precious.blood.(1996).eng.1cd', 'chunk_index': 3}
# {'name': 'battlebots.(2015).eng.1cd', 'chunk_index': 4}
# {'name': 'csi.crime.scene.investigation.s08.e16.two.and.a.half.deaths.(2008).eng.1cd', 'chunk_index': 5}
# {'name': 'royal.ashes.().eng.1cd', 'chunk_index': 6}
# {'name': 'return.to.seoul.(2022).eng.1cd', 'chunk_index': 7}
# {'name': 'idris.elba.king.of.speed.s01.e02.episode.1.2.(2013).eng.1cd', 'chunk_index': 8}
# {'name': 'tooth.pari.when.love.bites.s01.e08.episode.1.8.(2023).eng.1cd', 'chunk_index': 9}
# {'name': 'studio.one.s08.e30.the.arena.(1956).eng.1cd', 'chunk_index': 10}
# {'name': 'love.life.s02.e10.epilogue.(2021).eng.1cd', 'chunk_index': 11}
# {'name': 'scrubs.s03.e14.my.screwup.(2004).eng.1cd', 'chunk_index': 12}
# {'name': 'devotion.(2022).eng.1cd', 'chunk_index': 13}
# {'name': 'central.park.s03.e03.ice.ice.not.baby.(2022).eng.1cd', 'chunk_index': 14}
# {'name': 'walker.s01.e15.four.stones.in.hand.(2021).eng.1cd', 'chunk_index': 15}
# {'name': 'a.nashville.country.christmas.(2022).eng.1cd', 'chunk_index': 16}
# {'name': 'survivor.s21.e09.running.the.camp.(2010).eng.1cd', 'chunk_index': 17}
# {'name': 'fringe.s04.e08.back.to.where.youve.never.been.(2012).eng.1cd', 'chunk_index': 18}
# {'name': 'the.blue.whisper.episode.1.3.().eng.1cd', 'chunk_index': 19}
# {'name': 'castle.s03.e19.law.murder.(2011).eng.1cd', 'chunk_index': 20}
# {'name': 'idolish7.s02.e12.ripples.(2020).eng.1cd', 'chunk_index': 21}
# {'name': 'the.real.housewives.of.beverly.hills.s12.e16.altitude.adjustment.().eng.1cd', 'chunk_index': 22}
# {'name': 'suki.(2023).eng.1cd', 'chunk_index': 23}
# {'name': 'loan.wolves.(2022).eng.1cd', 'chunk_index': 24}
# {'name': 'hua.jai.sila.s01.e21.episode.1.21.(2019).eng.1cd', 'chunk_index': 25}
# {'name': 'academy.(2020).eng.1cd', 'chunk_index': 26}
# {'name': 'reign.s02.e12.banished.(2015).eng.1cd', 'chunk_index': 27}
# {'name': 'arctic.circle.s01.e03.myrsky.nousee.(2018).eng.1cd', 'chunk_index': 28}
# {'name': 'the.secret.of.skinwalker.ranch.s04.e01.over.and.out.of.this.world.(2023).eng.1cd', 'chunk_index': 29}
# {'name': 'shadowverse.s01.e04.somethings.special.(2020).eng.1cd', 'chunk_index': 30}
# {'name': 'avenue.5.s01.e02.and.then.hes.gonna.shoot.off.(2020).eng.1cd', 'chunk_index': 31}
# {'name': 'victoria.(2020).eng.1cd', 'chunk_index': 32}
# {'name': '90210.s02.e21.javianna.(2010).eng.1cd', 'chunk_index': 33}
# {'name': 'law.order.s22.e08.chain.of.command.(2022).eng.1cd', 'chunk_index': 34}
# {'name': 'the.scotts.s02.e06.episode.2.6.(2022).eng.1cd', 'chunk_index': 35}
# {'name': 'the.glass.reed.s01.e04.episode.1.4.(2015).eng.1cd', 'chunk_index': 36}
# {'name': 'in.sickness.and.in.health.s02.e04.episode.2.4.(1986).eng.1cd', 'chunk_index': 37}
# {'name': 'brighton.beach.memoirs.(1986).eng.1cd', 'chunk_index': 38}
# {'name': 'shababnikim.s01.e01.room.17.(2017).eng.1cd', 'chunk_index': 39}
# {'name': 'janosik.(1963).eng.2cd', 'chunk_index': 40}
# {'name': 'american.psycho.(2000).eng.1cd', 'chunk_index': 41}
# {'name': 'step.by.step.s07.e06.cant.buy.me.love.(1997).eng.1cd', 'chunk_index': 42}
# {'name': 'captain.sharif.s06.e10.piege.(2019).eng.1cd', 'chunk_index': 43}
# {'name': 'by.the.grace.of.the.gods.s01.e03.first.time.in.town.with.the.slimes.(2020).eng.1cd', 'chunk_index': 44}
# {'name': 'abunai.deka.(1986).eng.1cd', 'chunk_index': 45}
# {'name': 'scrubs.s09.e04.our.histories.(2009).eng.1cd', 'chunk_index': 46}
# {'name': 'south.park.s26.e02.the.worldwide.privacy.tour.(2023).eng.1cd', 'chunk_index': 47}
# {'name': 'van.helsing.s01.e02.seen.you.(2016).eng.1cd', 'chunk_index': 48}
# {'name': 'ncis.s11.e23.the.admirals.daughter.(2014).eng.1cd', 'chunk_index': 49}
# {'name': 'hungry.dog.blues.(2022).eng.1cd', 'chunk_index': 50}
# {'name': 'magnum.p.i.s01.e11.nowhere.to.hide.(2019).eng.1cd', 'chunk_index': 51}
# {'name': 'american.experience.s27.e03.klansville.u.s.a.(2015).eng.1cd', 'chunk_index': 52}
# {'name': 'lucifer.s05.e13.a.little.harmless.stalking.(2021).eng.1cd', 'chunk_index': 53}
# {'name': 'greys.anatomy.s02.e08.let.it.be.(2005).eng.1cd', 'chunk_index': 54}
# {'name': 'grantchester.s03.e06.episode.3.6.(2017).eng.1cd', 'chunk_index': 55}
# {'name': 'king.of.the.hill.s13.e17.manger.baby.einstein.(2009).eng.1cd', 'chunk_index': 56}
# {'name': 'connect.s01.e03.composition.(2022).eng.1cd', 'chunk_index': 57}
# {'name': 'earths.tropical.islands.s01.e03.hawaii.(2020).eng.1cd', 'chunk_index': 58}
# {'name': 'csi.ny.s08.e12.brooklyn.til.i.die.(2012).eng.1cd', 'chunk_index': 59}
# {'name': 'the.last.of.us.s01.e05.endure.and.survive.(2023).eng.1cd', 'chunk_index': 60}
# {'name': 'stargirl.s03.e01.frenemies.chapter.one.the.murder.(2022).eng.1cd', 'chunk_index': 61}
# {'name': 'its.beautiful.now.s01.e22.episode.1.22.(2022).eng.1cd', 'chunk_index': 62}
# {'name': 'interrogator.s01.e08.famous.last.words.(2022).eng.1cd', 'chunk_index': 63}
# {'name': 'wrath.a.seven.deadly.sins.story.().eng.1cd', 'chunk_index': 64}
# {'name': 'record.of.the.lodoss.war.s01.e11.madoushi.no.yabou.(1991).eng.1cd', 'chunk_index': 65}
# {'name': 'belair.s02.e02.speaking.truth.(2023).eng.1cd', 'chunk_index': 66}
# {'name': 'army.wives.s06.e07.system.failure.(2012).eng.1cd', 'chunk_index': 67}
# {'name': 'desperate.housewives.s07.e11.assassins.(2011).eng.1cd', 'chunk_index': 68}
# {'name': 'american.experience.s34.e01.sandra.day.oconnor.the.first.(2021).eng.1cd', 'chunk_index': 69}
# {'name': 'sexify.s02.e04.episode.2.4.(2023).eng.1cd', 'chunk_index': 70}
# {'name': 'in.the.dark.s04.e11.the.deep.end.(2022).eng.1cd', 'chunk_index': 71}
# {'name': 'vanished.with.beth.holloway.s01.e09.desirsmart.(2011).eng.1cd', 'chunk_index': 72}
# {'name': 'csi.vegas.s02.e04.koala.(2022).eng.1cd', 'chunk_index': 73}
# {'name': 'vietnam.a.television.history.s01.e01.roots.of.a.war.19451953.(1983).eng.1cd', 'chunk_index': 74}
# {'name': 'love.island.s08.e50.episode.50.(2022).eng.1cd', 'chunk_index': 75}
# {'name': 'tierra.incognita.s01.e01.the.labyrinth.(2022).eng.1cd', 'chunk_index': 76}
# {'name': 'extraordinary.s01.e02.magic.bullets.(2023).eng.1cd', 'chunk_index': 77}
# {'name': 'the.xfiles.s08.e03.patience.(2000).eng.1cd', 'chunk_index': 78}
# {'name': 'our.only.chance.s01.e05.mi.oasis.(2022).eng.1cd', 'chunk_index': 79}
# {'name': 'open.heart.s01.e09.password.(2015).eng.1cd', 'chunk_index': 80}
# {'name': 'friends.s08.e06.the.one.with.the.halloween.party.(2001).eng.1cd', 'chunk_index': 81}
# {'name': 'the.voice.s22.e05.the.blind.auditions.part.5.(2022).eng.1cd', 'chunk_index': 82}
# {'name': 'the.xfiles.s02.e07.3.(1994).eng.1cd', 'chunk_index': 83}
# {'name': 'csi.miami.s01.e16.evidence.of.things.unseen.(2003).eng.1cd', 'chunk_index': 84}
# {'name': 'heroes.s03.e25.chapter.twelve.an.invisible.thread.(2009).eng.1cd', 'chunk_index': 85}
# {'name': 'joint.venture.s02.e03.nem.tudo.sao.flores.(2022).eng.1cd', 'chunk_index': 86}
# {'name': 'teenage.girl.skip.day.(2022).eng.1cd', 'chunk_index': 87}
# {'name': 'miraculous.tales.of.ladybug.cat.noir.s01.e12.darkblade.(2015).eng.1cd', 'chunk_index': 88}
# {'name': 'ancient.apocalypse.s01.e05.legacy.of.the.sages.(2022).eng.1cd', 'chunk_index': 89}
# {'name': 'harley.quinn.s03.e09.climax.at.jazzapajizza.(2022).eng.1cd', 'chunk_index': 90}
# {'name': 'young.hercules.s01.e25.hercs.nemesis.(1998).eng.1cd', 'chunk_index': 91}
# {'name': 'the.middle.s07.e04.risky.business.(2015).eng.1cd', 'chunk_index': 92}
# {'name': 'devil.in.ohio.s01.e05.alight.(2022).eng.1cd', 'chunk_index': 93}
# {'name': 'leverage.redemption.s02.e11.the.belly.of.the.beast.job.(2023).eng.1cd', 'chunk_index': 94}
# {'name': 'saturday.night.live.s04.e19.maureen.stapletonlinda.ronstadtphoebe.snow.(1979).eng.1cd', 'chunk_index': 95}
# {'name': 'somebody.i.used.to.know.(2023).eng.1cd', 'chunk_index': 96}
# {'name': 'love.life.s01.e05.luke.ducharme.(2020).eng.1cd', 'chunk_index': 97}
# {'name': 'the.lord.of.the.rings.the.rings.of.power.s01.e04.the.great.wave.(2022).eng.1cd', 'chunk_index': 98}
# {'name': 'jamtara.sabka.number.ayega.s02.e02.episode.2.2.(2022).eng.1cd', 'chunk_index': 99}
# {'name': 'the.mindy.project.s01.e13.harry.sally.(2013).eng.1cd', 'chunk_index': 100}
# {'name': 'fire.country.s01.e08.bad.guy.(2022).eng.1cd', 'chunk_index': 101}
# {'name': 'the.nanny.s02.e26.fran.gets.mugged.(1995).eng.1cd', 'chunk_index': 102}
# {'name': 'shameless.s09.e14.found.(2019).eng.1cd', 'chunk_index': 103}
# {'name': 'bobs.burgers.s13.e13.stop.or.my.mom.will.sleuth.(2023).eng.1cd', 'chunk_index': 104}
# {'name': 'its.beautiful.now.s01.e44.episode.1.44.(2022).eng.1cd', 'chunk_index': 105}
# {'name': 'northern.exposure.s05.e20.a.wing.and.a.prayer.(1994).eng.1cd', 'chunk_index': 106}
# {'name': 'narcos.s02.e02.cambalache.(2016).eng.1cd', 'chunk_index': 107}
# {'name': '1899.s01.e05.the.calling.(2022).eng.1cd', 'chunk_index': 108}
# {'name': 'reign.s02.e10.mercy.(2014).eng.1cd', 'chunk_index': 109}
# {'name': 'fruits.basket.s03.e05.i.mean.you.know.right.(2021).eng.1cd', 'chunk_index': 110}
# {'name': 'iki.wo.hisomete.s01.e03.episode.1.3.(2021).eng.1cd', 'chunk_index': 111}
# {'name': 'beverly.hills.90210.s06.e08.gypsies.cramps.and.fleas.(1995).eng.1cd', 'chunk_index': 112}
# {'name': 'scrubs.s09.e05.our.mysteries.(2009).eng.1cd', 'chunk_index': 113}
# {'name': 'sexify.s02.e03.episode.2.3.(2023).eng.1cd', 'chunk_index': 114}
# {'name': 'murdoch.mysteries.s04.e01.tattered.and.torn.(2011).eng.1cd', 'chunk_index': 115}
# {'name': 'high.school.musical.the.musical.the.series.s03.e05.the.real.campers.of.shallow.lake.(2022).eng.1cd', 'chunk_index': 116}
# {'name': 'batwheels.s01.e05.bibis.doover.(2022).eng.1cd', 'chunk_index': 117}
# {'name': 'is.it.wrong.to.try.to.pick.up.girls.in.a.dungeon.s03.e10.invisible.(forced.breakthrough).(2020).eng.1cd', 'chunk_index': 118}
# {'name': 'one.step.more.to.the.sea.(2009).eng.1cd', 'chunk_index': 119}
# {'name': 'upright.s01.e01.day.one.(2019).eng.1cd', 'chunk_index': 120}
# {'name': 'my.life.is.murder.s03.e04.the.village.(2022).eng.1cd', 'chunk_index': 121}
# {'name': 'lart.du.crime.s02.e02.une.ombre.au.tableau.partie.2.(2018).eng.1cd', 'chunk_index': 122}
# {'name': 'shehulk.attorney.at.law.s01.e06.just.jen.(2022).eng.1cd', 'chunk_index': 123}
# {'name': 'my.childhood.(1972).eng.1cd', 'chunk_index': 124}
# {'name': 'the.nazis.a.warning.from.history.s01.e01.helped.into.power.(1997).eng.1cd', 'chunk_index': 125}
# {'name': 'murdoch.mysteries.s16.e08.i.still.know.what.you.did.last.autumn.(2022).eng.1cd', 'chunk_index': 126}
# {'name': 'may.it.please.the.court.s01.e04.episode.1.4.().eng.1cd', 'chunk_index': 127}
# {'name': '24.s01.e10.900.a.m.1000.a.m.(2002).eng.1cd', 'chunk_index': 128}
# {'name': 'phantom.signals.s01.e04.oblivion.calling.(2020).eng.1cd', 'chunk_index': 129}
# {'name': 'what.josiah.saw.(2021).eng.1cd', 'chunk_index': 130}
# {'name': 'velma.s01.e04.velma.makes.a.list.(2023).eng.1cd', 'chunk_index': 131}
# {'name': 'how.to.get.away.with.murder.s01.e05.were.not.friends.(2014).eng.1cd', 'chunk_index': 132}
# {'name': 'the.ateam.s03.e02.the.bend.in.the.river.part.1.(1984).eng.1cd', 'chunk_index': 133}
# {'name': 'stargate.atlantis.s04.e08.the.seer.(2007).eng.1cd', 'chunk_index': 134}
# {'name': 'your.honor.s02.e07.part.seventeen.(2023).eng.1cd', 'chunk_index': 135}
# {'name': 'the.son.(2022).eng.1cd', 'chunk_index': 136}
# {'name': 'tiny.beautiful.things.s01.e04.under.the.stars.(2023).eng.1cd', 'chunk_index': 137}
# {'name': 'this.is.us.s01.e15.jack.pearsons.son.(2017).eng.1cd', 'chunk_index': 138}
# {'name': 'particles.(2019).eng.1cd', 'chunk_index': 139}
# {'name': 'once.again.s01.e63.episode.1.63.(2020).eng.1cd', 'chunk_index': 140}
# {'name': 'the.brave.ones.s01.e05.episode.1.5.(2022).eng.1cd', 'chunk_index': 141}
# {'name': 'trafficked.with.mariana.van.zeller.s01.e01.scams.(2020).eng.1cd', 'chunk_index': 142}
# {'name': 'samurai.jack.s04.e05.episode.xliv.the.princess.and.the.bounty.hunters.(2003).eng.1cd', 'chunk_index': 143}
# {'name': 'egypts.unexplained.files.s01.e06.curse.of.the.screaming.mummy.(2019).eng.1cd', 'chunk_index': 144}
# {'name': 'you.cant.escape.me.(2023).eng.1cd', 'chunk_index': 145}
# {'name': 'robo.mundial.s01.e01.siamo.fuori.(2022).eng.1cd', 'chunk_index': 146}
# {'name': 'saturday.night.live.s05.e03.bill.russellchicago.(1979).eng.1cd', 'chunk_index': 147}
# {'name': 'charlies.angels.s03.e10.angel.on.my.mind.(1978).eng.1cd', 'chunk_index': 148}
# {'name': 'circuit.breakers.s01.e04.entangled.(2022).eng.1cd', 'chunk_index': 149}
# {'name': 'bloodlines.the.jersey.devil.curse.(2022).eng.1cd', 'chunk_index': 150}
# {'name': 'paper.girls.s01.e06.matinee.(2022).eng.1cd', 'chunk_index': 151}
# {'name': 'the.rookie.feds.s01.e05.felicia.(2022).eng.1cd', 'chunk_index': 152}
# {'name': 'charmed.s01.e22.deja.vu.all.over.again.(1999).eng.1cd', 'chunk_index': 153}
# {'name': 'hatching.(2022).eng.1cd', 'chunk_index': 154}
# {'name': 'black.snow.s01.e03.ezekiel.(2023).eng.1cd', 'chunk_index': 155}
# {'name': 'saturday.night.fever.(1977).eng.1cd', 'chunk_index': 156}
# {'name': 'picket.fences.s03.e04.enemy.lines.(1994).eng.1cd', 'chunk_index': 157}
# {'name': 'the.bastard.son.the.devil.himself.s01.e06.episode.1.6.(2022).eng.1cd', 'chunk_index': 158}
# {'name': 'the.magical.revolution.of.the.reincarnated.princess.and.the.genius.young.lady.s01.e03.the.rainbow.magic.sword.of.longing.and.reminiscence.(2023).eng.1cd', 'chunk_index': 159}
# {'name': 'my.dad.marie.(2020).eng.1cd', 'chunk_index': 160}
# {'name': 'shanghai.kiss.(2007).eng.1cd', 'chunk_index': 161}
# {'name': 'magic.of.disneys.animal.kingdom.s02.e04.okapi.bundle.of.joy.(2023).eng.1cd', 'chunk_index': 162}
# {'name': 'metel.(1965).eng.1cd', 'chunk_index': 163}
# {'name': 'greys.anatomy.s12.e17.i.wear.the.face.(2016).eng.1cd', 'chunk_index': 164}
# {'name': 'still.life.of.memories.(2018).eng.1cd', 'chunk_index': 165}
# {'name': 'hope.(2013).eng.1cd', 'chunk_index': 166}
# {'name': 'workaholics.s06.e05.gone.catfishing.(2016).eng.1cd', 'chunk_index': 167}
# {'name': 'young.sheldon.s06.e03.passions.harvest.and.a.sheldocracy.(2022).eng.1cd', 'chunk_index': 168}
# {'name': 'young.royals.s02.e02.episode.2.2.(2022).eng.1cd', 'chunk_index': 169}
# {'name': 'mars.venus.(2007).eng.1cd', 'chunk_index': 170}
# {'name': 'family.guy.s16.e17.switch.the.flip.(2018).eng.1cd', 'chunk_index': 171}
# {'name': 'the.latin.kitchen.s01.e09.spanish.coastal.recipes.(2017).eng.1cd', 'chunk_index': 172}
# {'name': 'csi.miami.s01.e10.a.horrible.mind.(2002).eng.1cd', 'chunk_index': 173}
# {'name': 'scrubs.s05.e04.my.jiggly.ball.(2006).eng.1cd', 'chunk_index': 174}
# {'name': 'human.resources.(2021).eng.1cd', 'chunk_index': 175}
# {'name': 'late.night.story.s01.e02.the.emissary.(1978).eng.1cd', 'chunk_index': 176}
# {'name': 'escape.to.athena.(1979).eng.1cd', 'chunk_index': 177}
# {'name': 'river.monsters.s03.e03.silent.assassin.(2011).eng.1cd', 'chunk_index': 178}
# {'name': 'fired.on.mars.s01.e01.the.one.way.trip.(2023).eng.1cd', 'chunk_index': 179}
# {'name': 'detective.school.q.s01.e33.kateika.shitsu.no.nazo.(2003).eng.1cd', 'chunk_index': 180}
# {'name': 'the.boys.s01.e07.the.selfpreservation.society.(2019).eng.1cd', 'chunk_index': 181}
# {'name': 'sister.sister.s05.e16.ladies.choice.(1998).eng.1cd', 'chunk_index': 182}
# {'name': 'the.law.according.to.lidia.poet.s01.e03.episode.1.3.(2023).eng.1cd', 'chunk_index': 183}
# {'name': 'veep.s04.e01.joint.session.(2015).eng.1cd', 'chunk_index': 184}
# {'name': 'the.story.of.the.jews.s01.e04.over.the.rainbow.(2013).eng.1cd', 'chunk_index': 185}
# {'name': 'happy.valley.s01.e06.episode.1.6.(2014).eng.1cd', 'chunk_index': 186}
# {'name': 'big.time.rush.s01.e15.big.time.sparks.(2010).eng.1cd', 'chunk_index': 187}
# {'name': 'ladies.should.listen.(1934).eng.1cd', 'chunk_index': 188}
# {'name': 'physical.s02.e10.dont.you.say.its.over.(2022).eng.1cd', 'chunk_index': 189}
# {'name': 'the.clock.(1945).eng.1cd', 'chunk_index': 190}
# {'name': 'the.jewel.in.the.crown.s01.e07.daughters.of.the.regiment.(1984).eng.1cd', 'chunk_index': 191}
# {'name': 'hidden.assets.s01.e01.episode.1.1.(2021).eng.1cd', 'chunk_index': 192}
# {'name': 'the.ghost.and.molly.mcgee.s02.e03.faint.of.arta.soda.to.remember.(2023).eng.1cd', 'chunk_index': 193}
# {'name': 'call.me.chihiro.(2023).eng.1cd', 'chunk_index': 194}
# {'name': 'amityville.karen.(2022).eng.1cd', 'chunk_index': 195}
# {'name': 'nova.s46.e15.the.planets.saturn.(2019).eng.1cd', 'chunk_index': 196}
# {'name': 'nature.s33.e13.animal.homes.location.location.location.(2015).eng.1cd', 'chunk_index': 197}
# {'name': 'wan.pisu.(1999).eng.1cd', 'chunk_index': 198}
# {'name': 'ginny.georgia.s02.e05.latkes.are.lit.(2023).eng.1cd', 'chunk_index': 199}
# {'name': 'amber.brown.s01.e03.no.place.like.two.homes.(2022).eng.1cd', 'chunk_index': 200}
# {'name': 'tears.on.fire.s01.e06.trauma.(2021).eng.1cd', 'chunk_index': 201}
# {'name': 'the.grid.s01.e01.episode.1.1.(2004).eng.1cd', 'chunk_index': 202}
# {'name': 'everybody.hates.chris.s03.e11.everybody.hates.the.port.authority.(2008).eng.1cd', 'chunk_index': 203}
# {'name': 'shark.tank.s14.e08.episode.14.8.(2022).eng.1cd', 'chunk_index': 204}
# {'name': 'lucky.life.(2010).eng.1cd', 'chunk_index': 205}
# {'name': 'street.of.chance.(1942).eng.1cd', 'chunk_index': 206}
# {'name': 'industry.s02.e03.the.fool.(2022).eng.1cd', 'chunk_index': 207}
# {'name': 'naruto.shippuden.s01.e137.amaterasu.(2009).eng.1cd', 'chunk_index': 208}
# {'name': 'def.comedy.jam.s01.e07.episode.1.7.(1992).eng.1cd', 'chunk_index': 209}
# {'name': 'love.in.wolf.creek.(2022).eng.1cd', 'chunk_index': 210}
# {'name': 'magnum.p.i.s05.e04.nsfw.(2023).eng.1cd', 'chunk_index': 211}
# {'name': 'britains.most.evil.killers.s01.e08.dennis.nilsen.(2017).eng.1cd', 'chunk_index': 212}
# {'name': 'classroom.of.the.elite.s02.e07.to.doubt.everything.or.to.believe.everything.are.two.equally.convenient.solutions.both.dispense.with.the.necessity.of.reflection.(2022).eng.1cd', 'chunk_index': 213}
# {'name': 'futurama.s02.e07.a.head.in.the.polls.(1999).eng.1cd', 'chunk_index': 214}
# {'name': 'the.mulligan.(2022).eng.1cd', 'chunk_index': 215}
# {'name': 'auggie.rose.(2000).eng.1cd', 'chunk_index': 216}
# {'name': 'darby.and.joan.s01.e08.episode.1.8.(2022).eng.1cd', 'chunk_index': 217}
# {'name': 'record.of.ragnarok.s02.e09.resonance.(2023).eng.1cd', 'chunk_index': 218}
# {'name': 'dallas.s01.e03.the.price.you.pay.(2012).eng.1cd', 'chunk_index': 219}
# {'name': 'sound.of.silence.(2023).eng.1cd', 'chunk_index': 220}
# {'name': 'pepsi.wheres.my.jet.s01.e01.the.kid.from.seattle.(2022).eng.1cd', 'chunk_index': 221}
# {'name': 'magnum.p.i.s03.e03.no.way.out.(2020).eng.1cd', 'chunk_index': 222}
# {'name': 'as.if.s02.e08.resimdeki.unlu.(2022).eng.1cd', 'chunk_index': 223}
# {'name': 'break.point.s01.e03.california.dreaming.(2023).eng.1cd', 'chunk_index': 224}
# {'name': 'madam.secretary.s06.e10.leaving.the.station.(2019).eng.1cd', 'chunk_index': 225}
# {'name': 'poldark.s05.e01.episode.5.1.(2019).eng.1cd', 'chunk_index': 226}
# {'name': 'hannibal.(1959).eng.1cd', 'chunk_index': 227}
# {'name': 'ray.donovan.s07.e07.the.transfer.agent.(2019).eng.1cd', 'chunk_index': 228}
# {'name': 'fruits.basket.s02.e11.all.mine.(2020).eng.1cd', 'chunk_index': 229}
# {'name': 'love.life.s02.e06.becca.evans.part.ii.(2021).eng.1cd', 'chunk_index': 230}
# {'name': 'magnum.p.i.s05.e05.welcome.to.paradise.now.die.(2023).eng.1cd', 'chunk_index': 231}
# {'name': 'the.middle.s02.e22.the.prom.(2011).eng.1cd', 'chunk_index': 232}
# {'name': 'the.other.tom.(2021).eng.1cd', 'chunk_index': 233}
# {'name': 'once.upon.a.time.s02.e02.we.are.both.(2012).eng.1cd', 'chunk_index': 234}
# {'name': 'ncis.hawaii.s02.e05.sudden.death.(2022).eng.1cd', 'chunk_index': 235}
# {'name': 'turkish.delight.(1973).eng.1cd', 'chunk_index': 236}
# {'name': 'silk.stalkings.s08.e09.the.loneliest.number.(1998).eng.1cd', 'chunk_index': 237}
# {'name': 'strange.voyage.(1964).eng.1cd', 'chunk_index': 238}
# {'name': 'most.dangerous.game.s02.e10.one.way.ticket.().eng.1cd', 'chunk_index': 239}
# {'name': 'saturdays.s01.e01.skates.lies.videos.(2023).eng.1cd', 'chunk_index': 240}
# {'name': 'third.watch.s01.e08.history.of.the.world.(1999).eng.1cd', 'chunk_index': 241}
# {'name': 'survivor.s36.e05.fate.is.the.homie.(2018).eng.1cd', 'chunk_index': 242}
# {'name': 'beauty.and.the.beast.s02.e14.redemption.(2014).eng.1cd', 'chunk_index': 243}
# {'name': 'sister.sister.s06.e06.bum.rap.(1998).eng.1cd', 'chunk_index': 244}
# {'name': 'echo.3.s01.e02.tora.bora.in.the.city.(2022).eng.1cd', 'chunk_index': 245}
# {'name': 'goyokin.(1969).eng.1cd', 'chunk_index': 246}
# {'name': 'the.mindy.project.s02.e04.magic.morgan.(2013).eng.1cd', 'chunk_index': 247}
# {'name': 'the.dresden.files.s01.e10.what.about.bob.(2007).eng.1cd', 'chunk_index': 248}
# {'name': 'o.sabor.das.margaridas.s02.e02.a.laltra.riva.(2020).eng.1cd', 'chunk_index': 249}
# {'name': 'arjun.the.warrior.prince.(2012).eng.1cd', 'chunk_index': 250}
# {'name': 'nashville.s01.e14.dear.brother.(2013).eng.1cd', 'chunk_index': 251}
# {'name': 'dwdd.university.(2013).eng.1cd', 'chunk_index': 252}
# {'name': 'beverly.hills.90210.s04.e11.take.back.the.night.(1993).eng.1cd', 'chunk_index': 253}
# {'name': 'cactus.jack.(2022).eng.1cd', 'chunk_index': 254}
# {'name': 'the.epstein.chronicles.s00.e20.a.look.back.prince.andrew.the.musical.(2022).eng.1cd', 'chunk_index': 255}
# {'name': 'combat.obscura.(2018).eng.1cd', 'chunk_index': 256}
# {'name': 'survivor.s39.e07.i.was.born.at.night.but.not.last.night.(2019).eng.1cd', 'chunk_index': 257}
# {'name': 'hot.in.cleveland.s03.e22.storage.wars.(2012).eng.1cd', 'chunk_index': 258}
# {'name': 'mikey.and.nicky.(1976).eng.1cd', 'chunk_index': 259}
# {'name': 'welcome.to.chippendales.s01.e08.switzerland.(2023).eng.1cd', 'chunk_index': 260}
# {'name': 'nature.s36.e15.natural.born.rebels.the.mating.game.(2018).eng.1cd', 'chunk_index': 261}
# {'name': 'the.jeffersons.s09.e02.laundry.is.a.tough.town.part.2.(1982).eng.1cd', 'chunk_index': 262}
# {'name': 'hey.we.like.to.interject.this.way.animated.(full.4k).(2022).eng.1cd', 'chunk_index': 263}
# {'name': 'the.crown.s05.e05.the.way.ahead.(2022).eng.1cd', 'chunk_index': 264}
# {'name': 'tropical.heat.s01.e01.hard.case.(1991).eng.1cd', 'chunk_index': 265}
# {'name': 'tiny.beautiful.things.s01.e01.pilot.(2023).eng.1cd', 'chunk_index': 266}
# {'name': 'revenge.of.others.s01.e03.episode.1.3.(2022).eng.1cd', 'chunk_index': 267}
# {'name': 'family.guy.s05.e06.prick.up.your.ears.(2006).eng.1cd', 'chunk_index': 268}
# {'name': 'the.americans.s01.e06.trust.me.(2013).eng.1cd', 'chunk_index': 269}
# {'name': 'my.name.is.earl.s01.e20.boogeyman.(2006).eng.1cd', 'chunk_index': 270}
# {'name': 'secrets.of.summer.s02.e07.girls.jam.(2022).eng.1cd', 'chunk_index': 271}
# {'name': 'begstvo.mistera.makkinli.(1975).eng.1cd', 'chunk_index': 272}
# {'name': 'a.kismet.christmas.(2022).eng.1cd', 'chunk_index': 273}
# {'name': 'northern.exposure.s04.e23.mud.and.blood.(1993).eng.1cd', 'chunk_index': 274}
# {'name': 'the.naked.jungle.(1954).eng.1cd', 'chunk_index': 275}
# {'name': 'survivor.s21.e03.glitter.in.their.eyes.(2010).eng.1cd', 'chunk_index': 276}
# {'name': 'nova.s45.e101.nova.wonders.what.are.animals.saying.(2018).eng.1cd', 'chunk_index': 277}
# {'name': 'major.crimes.s01.e08.dismissed.with.prejudice.(2012).eng.1cd', 'chunk_index': 278}
# {'name': 'rosss.game.dungeon.(2013).eng.1cd', 'chunk_index': 279}
# {'name': 'the.secret.of.kells.(2009).eng.1cd', 'chunk_index': 280}
# {'name': 'the.nanny.s06.e16.the.producers.(1999).eng.1cd', 'chunk_index': 281}
# {'name': 'king.of.the.hill.s10.e12.24.hour.propane.people.(2006).eng.1cd', 'chunk_index': 282}
# {'name': 'guyver.the.bioboosted.armor.s01.e04.tasogare.no.raihosha.(2005).eng.1cd', 'chunk_index': 283}
# {'name': 'high.heat.s01.e05.sabes.donde.te.estas.metiendo.(2022).eng.1cd', 'chunk_index': 284}
# {'name': 'our.boys.s01.e02.chapter.2.i.love.toto.(2019).eng.1cd', 'chunk_index': 285}
# {'name': 'in.love.all.over.again.s01.e08.el.poder.de.las.palabras.(2023).eng.1cd', 'chunk_index': 286}
# {'name': 'blocco.181.s01.e07.episode.1.7.(2022).eng.1cd', 'chunk_index': 287}
# {'name': 'medium.s01.e13.being.mrs.olearys.cow.(2005).eng.1cd', 'chunk_index': 288}
# {'name': 'titans.s03.e11.the.call.is.coming.from.inside.the.house.(2021).eng.1cd', 'chunk_index': 289}
# {'name': 'the.yakuzas.guide.to.babysitting.s01.e02.a.kind.person.(2022).eng.1cd', 'chunk_index': 290}
# {'name': 'walker.independence.s01.e04.pax.romana.(2022).eng.1cd', 'chunk_index': 291}
# {'name': 'the.rookie.feds.s01.e14.the.offer.(2023).eng.1cd', 'chunk_index': 292}
# {'name': 'the.americans.s01.e06.trust.me.(2013).eng.1cd', 'chunk_index': 293}
# {'name': 'nightflyers.s01.e09.icarus.(2018).eng.1cd', 'chunk_index': 294}
# {'name': 'csi.crime.scene.investigation.s09.e03.art.imitates.life.(2008).eng.1cd', 'chunk_index': 295}
# {'name': 'lost.islands.(2008).eng.1cd', 'chunk_index': 296}
# {'name': 'superman.lois.s03.e05.head.on.(2023).eng.1cd', 'chunk_index': 297}
# {'name': 'tokyo.girl.s01.e08.episode.8.toyosu.endangered.species.that.wont.go.extinct.(2017).eng.1cd', 'chunk_index': 298}
# {'name': 'lopez.vs.lopez.s01.e02.lopez.vs.anxiety.(2022).eng.1cd', 'chunk_index': 299}
# {'name': 'reservation.dogs.s02.e03.roofing.(2022).eng.1cd', 'chunk_index': 300}
# {'name': 'medium.s04.e15.being.joey.carmichael.(2008).eng.1cd', 'chunk_index': 301}
# {'name': 'the.ghost.and.the.tout.too.(2021).eng.1cd', 'chunk_index': 302}
# {'name': 'cannibal.holocaust.(1980).eng.1cd', 'chunk_index': 303}
# {'name': 'srimulat.hil.yang.mustahal.babak.pertama.(2022).eng.1cd', 'chunk_index': 304}
# {'name': 'big.love.s02.e11.take.me.as.i.am.(2007).eng.1cd', 'chunk_index': 305}
# {'name': 'she.and.her.perfect.husband.s01.e12.episode.1.12.(2022).eng.1cd', 'chunk_index': 306}
# {'name': 'the.abbott.and.costello.show.s02.e21.the.pigeon.(1954).eng.1cd', 'chunk_index': 307}
# {'name': 'american.experience.s10.e01.truman.part.i.(1997).eng.1cd', 'chunk_index': 308}
# {'name': 'just.for.today.s01.e03.episode.1.3.(2019).eng.1cd', 'chunk_index': 309}
# {'name': 'beavis.and.butthead.s01.e11.refuse.servicedownward.dumbass.(2022).eng.1cd', 'chunk_index': 310}
# {'name': 'jackie.chan.adventures.s02.e21.scouts.honor.(2001).eng.1cd', 'chunk_index': 311}
# {'name': 'kakegurui.twin.s01.e01.a.girl.named.mary.saotome.(2022).eng.1cd', 'chunk_index': 312}
# {'name': 'yowamushi.pedal.s04.e06.sohoku.shaken.(2018).eng.1cd', 'chunk_index': 313}
# {'name': 'gangs.of.london.s02.e08.episode.2.8.(2022).eng.1cd', 'chunk_index': 314}
# {'name': 'the.jeffersons.s07.e20.florences.new.job.part.2.(1981).eng.1cd', 'chunk_index': 315}
# {'name': 'tom.clancys.jack.ryan.s03.e02.old.haunts.(2022).eng.1cd', 'chunk_index': 316}
# {'name': 'shababnikim.s01.e10.chiuv.(obligation).(2018).eng.1cd', 'chunk_index': 317}
# {'name': 'free.s03.e02.a.promise.on.a.shooting.star.(2018).eng.1cd', 'chunk_index': 318}
# {'name': 'st.elsewhere.s03.e21.murder.she.rote.(1985).eng.1cd', 'chunk_index': 319}
# {'name': 'the.jewel.in.the.crown.s01.e09.the.towers.of.silence.(1984).eng.1cd', 'chunk_index': 320}
# {'name': 'northern.exposure.s03.e01.the.bumpy.road.to.love.(1991).eng.1cd', 'chunk_index': 321}
# {'name': 'cash.register.s02.e18.fifty.million.(2020).eng.1cd', 'chunk_index': 322}
# {'name': 'the.tick.s03.e05.devil.in.diapers.(1996).eng.1cd', 'chunk_index': 323}
# {'name': 'love.triangle.(au).s01.e08.cinderellas.shoe.(2022).eng.1cd', 'chunk_index': 324}
# {'name': 'butterflies.(2018).eng.1cd', 'chunk_index': 325}
# {'name': 'inside.man.s01.e01.episode.1.1.(2022).eng.1cd', 'chunk_index': 326}
# {'name': 'home.economics.s03.e02.melatonin.10.mg.tablets.14.99.(2022).eng.1cd', 'chunk_index': 327}
# {'name': 'de.verraders.s02.e01.episode.2.1.(2021).eng.1cd', 'chunk_index': 328}
# {'name': 'the.dresden.files.s01.e09.the.other.dick.(2007).eng.1cd', 'chunk_index': 329}
# {'name': 'deinfluencer.(2022).eng.1cd', 'chunk_index': 330}
# {'name': 'byeoleun.nae.gaseume.s01.e14.episode.1.14.(1997).eng.1cd', 'chunk_index': 331}
# {'name': '8.out.of.10.cats.does.countdown.s05.e05.episode.7.6.(2015).eng.1cd', 'chunk_index': 332}
# {'name': 'step.up.high.water.s03.e09.bring.em.out.(2022).eng.1cd', 'chunk_index': 333}
# {'name': 'august.(2019).eng.1cd', 'chunk_index': 334}
# {'name': 'r.i.p.henry.s01.e08.er.4.lyfe.(2023).eng.1cd', 'chunk_index': 335}
# {'name': 'stuck.s01.e03.cucumbenaires.(2022).eng.1cd', 'chunk_index': 336}
# {'name': 'bia.s01.e36.episode.1.36.(2019).eng.1cd', 'chunk_index': 337}
# {'name': 'allo.allo.s05.e02.the.camera.in.the.potato.(1988).eng.1cd', 'chunk_index': 338}
# {'name': 'srugim.s03.e08.episode.3.8.(2011).eng.1cd', 'chunk_index': 339}
# {'name': 'rosss.game.dungeon.(2013).eng.1cd', 'chunk_index': 340}
# {'name': 'tiger.bunny.s01.e18.ignorance.is.bliss.(2011).eng.1cd', 'chunk_index': 341}
# {'name': 'the.blacklist.s10.e06.dr.laken.perillos.(no.70).conclusion.(2023).eng.1cd', 'chunk_index': 342}
# {'name': 'mercy.street.s02.e02.the.house.guest.(2017).eng.1cd', 'chunk_index': 343}
# {'name': 'a.million.little.things.s05.e05.no.place.like.home.(2023).eng.1cd', 'chunk_index': 344}
# {'name': 'big.mouth.s01.e16.episode.16.(2022).eng.1cd', 'chunk_index': 345}
# {'name': 'reservation.dogs.s02.e05.wide.net.(2022).eng.1cd', 'chunk_index': 346}
# {'name': 'king.of.the.hill.s13.e16.bad.news.bill.(2009).eng.1cd', 'chunk_index': 347}
# {'name': 'the.great.food.truck.race.s04.e01.i.left.my.food.cart.in.san.francisco.(2013).eng.1cd', 'chunk_index': 348}
# {'name': 'if.i.cant.have.you.(2023).eng.1cd', 'chunk_index': 349}
# {'name': 'heroes.s03.e24.chapter.eleven.i.am.sylar.(2009).eng.1cd', 'chunk_index': 350}
# {'name': 'the.clockmaker.of.st.paul.(1974).eng.1cd', 'chunk_index': 351}
# {'name': 'rupauls.drag.race.s15.e06.old.friends.gold.(2023).eng.1cd', 'chunk_index': 352}
# {'name': 'django.s01.e01.new.babylon.(2022).eng.1cd', 'chunk_index': 353}
# {'name': 'mom.s06.e13.big.floor.pillows.and.a.ball.of.fire.(2019).eng.1cd', 'chunk_index': 354}
# {'name': 'fall.(2022).eng.1cd', 'chunk_index': 355}
# {'name': 'as.time.goes.by.s03.e06.branching.out.(1994).eng.1cd', 'chunk_index': 356}
# {'name': 'at.last.the.1948.show.s02.e01.episode.2.1.(1967).eng.1cd', 'chunk_index': 357}
# {'name': 'american.dad.s03.e11.oedipal.panties.(2008).eng.1cd', 'chunk_index': 358}
# {'name': 'heroes.s03.e13.chapter.thirteen.dual.(2008).eng.1cd', 'chunk_index': 359}
# {'name': 'il.tredicesimo.apostolo.il.prescelto.s01.e09.il.villaggio.(2012).eng.1cd', 'chunk_index': 360}
# {'name': 'jojos.bizarre.adventure.s05.e25.bohemian.ecstatic.part.1.().eng.1cd', 'chunk_index': 361}
# {'name': 'magnum.p.i.s02.e14.a.game.of.cat.and.mouse.(2020).eng.1cd', 'chunk_index': 362}
# {'name': 'k.g.f.chapter.1.(2018).eng.1cd', 'chunk_index': 363}
# {'name': 'madam.secretary.s06.e08.ships.and.countries.(2019).eng.1cd', 'chunk_index': 364}
# {'name': 'save.me.from.everything.(2021).eng.1cd', 'chunk_index': 365}
# {'name': 'castle.s01.e01.flowers.for.your.grave.(2009).eng.1cd', 'chunk_index': 366}
# {'name': 'il.cacciatore.s03.e03.discendenza.(2021).eng.1cd', 'chunk_index': 367}
# {'name': 'scrubs.s06.e13.my.scrubs.(2007).eng.1cd', 'chunk_index': 368}
# {'name': 'the.secret.life.of.us.s04.e01.the.truth.about.cats.and.dogs.part.1.(2004).eng.1cd', 'chunk_index': 369}
# {'name': 'beverly.hills.90210.s08.e05.coming.home.(1997).eng.1cd', 'chunk_index': 370}
# {'name': 'murder.one.s01.e18.chapter.eighteen.(1996).eng.1cd', 'chunk_index': 371}
# {'name': 'westworld.s04.e06.fidelity.(2022).eng.1cd', 'chunk_index': 372}
# {'name': 'ella.enchanted.(2004).eng.1cd', 'chunk_index': 373}
# {'name': 'saturday.night.live.s01.e17.ron.nessenpatti.smith.group.(1976).eng.1cd', 'chunk_index': 374}
# {'name': 'the.island.fling.(1946).eng.1cd', 'chunk_index': 375}
# {'name': 'the.jeffersons.s06.e10.louise.vs.florence.(1979).eng.1cd', 'chunk_index': 376}
# {'name': 'berlin.station.s02.e04.do.the.right.thing.(2017).eng.1cd', 'chunk_index': 377}
# {'name': 'hua.jai.sila.s01.e25.episode.1.25.(2019).eng.1cd', 'chunk_index': 378}
# {'name': 'who.killed.jenni.rivera.s01.e03.target.or.victim.(2022).eng.1cd', 'chunk_index': 379}
# {'name': 'farewell.mr.haffmann.(2021).eng.1cd', 'chunk_index': 380}
# {'name': 'feng.shui.2.(2014).eng.1cd', 'chunk_index': 381}
# {'name': 'alfred.hitchcock.presents.s04.e29.banquos.chair.(1959).eng.1cd', 'chunk_index': 382}
# {'name': 'manpower.(2014).eng.1cd', 'chunk_index': 383}
# {'name': 'scrubs.s09.e02.our.drunk.friend.(2009).eng.1cd', 'chunk_index': 384}
# {'name': 'army.wives.s07.e02.from.the.ashes.(2013).eng.1cd', 'chunk_index': 385}
# {'name': 'all.creatures.great.and.small.s03.e01.second.time.lucky.(2022).eng.1cd', 'chunk_index': 386}
# {'name': 'leopard.skin.s01.e08.the.myth.of.the.guilty.murderess.(2022).eng.1cd', 'chunk_index': 387}
# {'name': 'home.movies.s01.e02.i.dont.do.well.in.parentteacher.conferences.(1999).eng.1cd', 'chunk_index': 388}
# {'name': 'bleach.s06.e08.rukia.sento.kaishi.koritsuki.shiroki.ha.(2007).eng.1cd', 'chunk_index': 389}
# {'name': 'brian.cox.seven.days.on.mars.(2022).eng.1cd', 'chunk_index': 390}
# {'name': 'queen.sugar.s07.e01.and.when.great.souls.die.(2022).eng.1cd', 'chunk_index': 391}
# {'name': 'shadow.and.bone.s02.e01.no.shelter.but.me.(2023).eng.1cd', 'chunk_index': 392}
# {'name': 'preacher.s02.e04.viktor.(2017).eng.1cd', 'chunk_index': 393}
# {'name': 'golden.kamuy.s03.e08.manslayer.(2020).eng.1cd', 'chunk_index': 394}
# {'name': 'murder.they.hope.s02.e01.cant.see.the.blood.for.the.trees.(2022).eng.1cd', 'chunk_index': 395}
# {'name': 'guyver.the.bioboosted.armor.s01.e24.seiatsuka.no.machi.de.(2006).eng.1cd', 'chunk_index': 396}
# {'name': 'dead.end.paranormal.park.s02.e03.the.trials.of.barney.(2022).eng.1cd', 'chunk_index': 397}
# {'name': 'margaret.(2011).eng.1cd', 'chunk_index': 398}
# {'name': 'sisters.for.life.(2021).eng.1cd', 'chunk_index': 399}
# {'name': 'nova.s44.e04.ultimate.cruise.ship.(2017).eng.1cd', 'chunk_index': 400}
# {'name': 'kung.fu.panda.the.dragon.knight.s02.e06.hide.the.lightening.(2023).eng.1cd', 'chunk_index': 401}
# {'name': 'the.bachelor.s27.e10.episode.27.10.(2023).eng.1cd', 'chunk_index': 402}
# {'name': 'two.and.a.half.men.s01.e14.i.cant.afford.hyenas.(2004).eng.1cd', 'chunk_index': 403}
# {'name': 'love.at.first.stream.(2021).eng.1cd', 'chunk_index': 404}
# {'name': 'american.dad.s02.e18.the.magnificent.steven.(2007).eng.1cd', 'chunk_index': 405}
# {'name': 'the.great.food.truck.race.s05.e04.high.steaks.in.okc.(2014).eng.1cd', 'chunk_index': 406}
# {'name': 'as.time.goes.by.s09.e05.you.must.remember.this.(2002).eng.1cd', 'chunk_index': 407}
# {'name': 'uss.christmas.(2020).eng.1cd', 'chunk_index': 408}
# {'name': 'the.ark.s01.e06.two.by.two.(2023).eng.1cd', 'chunk_index': 409}
# {'name': 'chicago.med.s08.e08.everyones.fighting.a.battle.you.know.nothing.about.(2022).eng.1cd', 'chunk_index': 410}
# {'name': 'old.people.(2022).eng.1cd', 'chunk_index': 411}
# {'name': 'selftape.s01.e01.episode.1.1.(2023).eng.1cd', 'chunk_index': 412}
# {'name': 'shameless.s01.e08.its.time.to.kill.the.turtle.(2011).eng.1cd', 'chunk_index': 413}
# {'name': 'csi.crime.scene.investigation.s02.e23.the.hunger.artist.(2002).eng.1cd', 'chunk_index': 414}
# {'name': 'fruits.basket.s01.e22.because.i.was.happy.(2019).eng.1cd', 'chunk_index': 415}
# {'name': 'flightrisk.(2022).eng.1cd', 'chunk_index': 416}
# {'name': 'mh370.the.plane.that.disappeared.s01.e02.the.hijack.(2023).eng.1cd', 'chunk_index': 417}
# {'name': 'desolasi.(2016).eng.1cd', 'chunk_index': 418}
# {'name': 'natural.world.s38.e02.natures.biggest.beasts.(2018).eng.1cd', 'chunk_index': 419}
# {'name': 'sayapsayap.patah.(2022).eng.1cd', 'chunk_index': 420}
# {'name': 'american.horror.story.s11.e04.black.out.(2022).eng.1cd', 'chunk_index': 421}
# {'name': 'samurai.rabbit.the.usagi.chronicles.s02.e08.the.chizu.stands.alone.(2022).eng.1cd', 'chunk_index': 422}
# {'name': 'my.name.is.earl.s01.e24.number.one.(2006).eng.1cd', 'chunk_index': 423}
# {'name': 'friends.s09.e21.the.one.with.the.fertility.test.(2003).eng.1cd', 'chunk_index': 424}
# {'name': 'married.with.children.s05.e14.look.whos.barking.(1991).eng.1cd', 'chunk_index': 425}
# {'name': 'non.non.biyori.s02.e09.we.looked.at.the.moon.together.(2015).eng.1cd', 'chunk_index': 426}
# {'name': 'cain.s01.e02.justices.(2012).eng.1cd', 'chunk_index': 427}
# {'name': 'young.sheldon.s05.e20.uncle.sheldon.and.a.hormonal.firecracker.(2022).eng.1cd', 'chunk_index': 428}
# {'name': 'marry.me.again.(2023).eng.1cd', 'chunk_index': 429}
# {'name': 'todos.mienten.s01.e02.episodio.2.(2022).eng.1cd', 'chunk_index': 430}
# {'name': 'taiwan.crime.stories.s01.e09.gravity.of.sin.3.(2023).eng.1cd', 'chunk_index': 431}
# {'name': 'crazy.wedding.2.(2019).eng.1cd', 'chunk_index': 432}
# {'name': 'run.silent.run.deep.(1958).eng.1cd', 'chunk_index': 433}
# {'name': 'rabin.the.last.day.(2015).eng.1cd', 'chunk_index': 434}
# {'name': 'american.dad.s04.e01.1600.candles.(2008).eng.1cd', 'chunk_index': 435}
# {'name': 'beti.bete.(1964).eng.1cd', 'chunk_index': 436}
# {'name': 'father.brown.s10.e05.the.hidden.man.(2023).eng.1cd', 'chunk_index': 437}
# {'name': 'the.white.lotus.s02.e01.ciao.(2022).eng.1cd', 'chunk_index': 438}
# {'name': 'the.middle.s07.e15.hecks.at.a.movie.(2016).eng.1cd', 'chunk_index': 439}
# {'name': 'belascoaran.pi.s01.e02.cosa.facil.(2022).eng.1cd', 'chunk_index': 440}
# {'name': 'garireo.s02.e05.episode.2.5.(2013).eng.1cd', 'chunk_index': 441}
# {'name': 'tropical.heat.s03.e28.spiders.tale.(1993).eng.1cd', 'chunk_index': 442}
# {'name': 'growing.up.s01.e02.episode.1.2.(2022).eng.1cd', 'chunk_index': 443}
# {'name': 'army.wives.s06.e10.after.action.report.(2012).eng.1cd', 'chunk_index': 444}
# {'name': 'walker.s02.e04.its.not.what.you.think.(2021).eng.1cd', 'chunk_index': 445}
# {'name': 'this.is.us.s03.e14.the.graduates.(2019).eng.1cd', 'chunk_index': 446}
# {'name': 'heroes.s02.e07.chapter.seven.out.of.time.(2007).eng.1cd', 'chunk_index': 447}
# {'name': 'entourage.s06.e08.the.sorkin.notes.(2009).eng.1cd', 'chunk_index': 448}
# {'name': 'reign.s04.e09.pulling.strings.(2017).eng.1cd', 'chunk_index': 449}
# {'name': 'the.inhabitant.(2022).eng.1cd', 'chunk_index': 450}
# {'name': 'detective.dee.and.resurrection.from.the.dead.(2022).eng.1cd', 'chunk_index': 451}
# {'name': 'the.neighborhood.s05.e01.welcome.back.to.the.neighborhood.(2022).eng.1cd', 'chunk_index': 452}
# {'name': 'german.crime.story.gefesselt.s01.e03.fessel.mich.(2023).eng.1cd', 'chunk_index': 453}
# {'name': 'killer.design.(2022).eng.1cd', 'chunk_index': 454}
# {'name': 'house.of.the.dragon.s01.e05.we.light.the.way.(2022).eng.1cd', 'chunk_index': 455}
# {'name': 'call.me.fitz.s01.e07.diving.bell.and.the.barbara.(2010).eng.1cd', 'chunk_index': 456}
# {'name': 'unforgettable.s04.e04.dollar.and.scents.(2015).eng.1cd', 'chunk_index': 457}
# {'name': 'maneater.(2022).eng.1cd', 'chunk_index': 458}
# {'name': 'the.xfiles.s09.e06.trust.no.1.(2002).eng.1cd', 'chunk_index': 459}
# {'name': 'upstairs.downstairs.s05.e04.the.joy.ride.(1975).eng.1cd', 'chunk_index': 460}
# {'name': 'csi.crime.scene.investigation.s07.e07.post.mortem.(2006).eng.1cd', 'chunk_index': 461}
# {'name': 'koala.man.s01.e02.deep.pockets.(2023).eng.1cd', 'chunk_index': 462}
# {'name': 'funeral.for.a.dog.s01.e04.shitty.city.(2022).eng.1cd', 'chunk_index': 463}
# {'name': 'noir.comme.le.souvenir.(1995).eng.1cd', 'chunk_index': 464}
# {'name': 'hot.skull.s01.e08.my.name.doesnt.matter.(2022).eng.1cd', 'chunk_index': 465}
# {'name': 'the.low.tone.club.(2022).eng.1cd', 'chunk_index': 466}
# {'name': 'american.experience.s31.e06.chasing.the.moon.a.place.beyond.the.sky.(2019).eng.1cd', 'chunk_index': 467}
# {'name': 'paradise.pd.s04.e02.diddys.home.(2022).eng.1cd', 'chunk_index': 468}
# {'name': 'castle.s06.e16.room.147.(2014).eng.1cd', 'chunk_index': 469}
# {'name': 'kiss.kiss.(2022).eng.1cd', 'chunk_index': 470}
# {'name': 'the.xfiles.s07.e19.hollywood.a.d.(2000).eng.1cd', 'chunk_index': 471}
# {'name': 'hot.in.cleveland.s06.e15.all.dolled.up.(2015).eng.1cd', 'chunk_index': 472}
# {'name': 'high.plains.drifter.(1973).eng.1cd', 'chunk_index': 473}
# {'name': 'total.control.s02.e02.episode.2.2.(2021).eng.1cd', 'chunk_index': 474}
# {'name': 'the.resident.s06.e07.the.chimera.(2022).eng.1cd', 'chunk_index': 475}
# {'name': 'la.part.des.lions.(1971).eng.1cd', 'chunk_index': 476}
# {'name': 'rise.of.empires.ottoman.s02.e04.brothers.no.more.(2022).eng.1cd', 'chunk_index': 477}
# {'name': 'horrible.histories.s01.e11.episode.1.11.(2009).eng.1cd', 'chunk_index': 478}
# {'name': 'men.of.plastic.(2022).eng.1cd', 'chunk_index': 479}
# {'name': 'the.jeffersons.s08.e07.florence.did.it.different.part.2.(1981).eng.1cd', 'chunk_index': 480}
# {'name': 'the.xfiles.s01.e16.young.at.heart.(1994).eng.1cd', 'chunk_index': 481}
# {'name': 'ancient.engineering.s01.e04.secrets.of.the.pyramids.(2021).eng.1cd', 'chunk_index': 482}
# {'name': 'sister.sister.s06.e08.greek.to.me.(1998).eng.1cd', 'chunk_index': 483}
# {'name': 'better.call.saul.s06.e06.axe.and.grind.(2022).eng.1cd', 'chunk_index': 484}
# {'name': 'natures.strangest.mysteries.solved.s01.e06.zombie.spider.(2019).eng.1cd', 'chunk_index': 485}
# {'name': 'two.and.a.half.men.s06.e06.its.always.nazi.week.(2008).eng.1cd', 'chunk_index': 486}
# {'name': 'spaces.deepest.secrets.spaces.great.wall.().eng.1cd', 'chunk_index': 487}
# {'name': 'army.wives.s07.e09.blood.and.treasure.(2013).eng.1cd', 'chunk_index': 488}
# {'name': 'dr.slump.s01.e20.jikou.no.chibikko.akuma.chibirukun.(1998).eng.1cd', 'chunk_index': 489}
# {'name': 'knight.club.(2001).eng.1cd', 'chunk_index': 490}
# {'name': 'champion.(2017).eng.1cd', 'chunk_index': 491}
# {'name': 'cagney.lacey.s01.e05.suffer.the.children.(1982).eng.1cd', 'chunk_index': 492}
# {'name': 'csi.ny.s04.e08.buzzkill.(2007).eng.1cd', 'chunk_index': 493}
# {'name': 'supercar.s02.e07.the.skys.the.limit.(1962).eng.1cd', 'chunk_index': 494}
# {'name': 'studio.one.s08.e30.the.arena.(1956).eng.1cd', 'chunk_index': 495}
# {'name': 'army.of.darkness.(1992).eng.1cd', 'chunk_index': 496}
# {'name': 'jail.(2021).eng.1cd', 'chunk_index': 497}
# {'name': 'as.time.goes.by.s06.e01.the.stalker.(1997).eng.1cd', 'chunk_index': 498}
# {'name': 'victoria.(2016).eng.1cd', 'chunk_index': 499}
# {'name': 'csi.crime.scene.investigation.s15.e08.rubbery.homicide.(2014).eng.1cd', 'chunk_index': 500}
# {'name': 'empire.s06.e01.what.is.love.(2019).eng.1cd', 'chunk_index': 501}
# {'name': 'the.mighty.ones.s04.e01.battle.of.the.babiesnorman.(2022).eng.1cd', 'chunk_index': 502}
# {'name': 'red.rose.s01.e02.the.garden.(2022).eng.1cd', 'chunk_index': 503}
# {'name': 'alice.in.borderland.s02.e02.episode.2.2.(2022).eng.1cd', 'chunk_index': 504}
# {'name': 'dance.100.s01.e03.episode.1.3.(2023).eng.1cd', 'chunk_index': 505}
# {'name': 'murdoch.mysteries.s12.e13.murdoch.and.the.undetectable.man.(2019).eng.1cd', 'chunk_index': 506}
# {'name': 'major.crimes.s04.e10.fifth.dynasty.(2015).eng.1cd', 'chunk_index': 507}
# {'name': 'murdoch.mysteries.s01.e08.still.waters.(2008).eng.1cd', 'chunk_index': 508}
# {'name': 'american.experience.s12.e02.new.york.part.ii.order.and.disorder.(1999).eng.1cd', 'chunk_index': 509}
# {'name': 'family.guy.s16.e08.crimes.and.megs.demeanor.(2017).eng.1cd', 'chunk_index': 510}
# {'name': 'little.miss.sunshine.(2006).eng.1cd', 'chunk_index': 511}
# {'name': 'i.bastardi.di.pizzofalcone.s02.e03.gioielli.(2018).eng.1cd', 'chunk_index': 512}
# {'name': 'desperate.housewives.s02.e20.it.wasnt.meant.to.happen.(2006).eng.1cd', 'chunk_index': 513}
# {'name': 'reign.s04.e14.a.bride.a.box.a.body.(2017).eng.1cd', 'chunk_index': 514}
# {'name': 'from.s02.e03.tether.(2023).eng.1cd', 'chunk_index': 515}
# {'name': 'freemans.mind.s04.e05.freemans.mind.episode.34.(2011).eng.1cd', 'chunk_index': 516}
# {'name': 'american.manhunt.the.boston.marathon.bombing.s01.e02.episode.1.2.(2023).eng.1cd', 'chunk_index': 517}
# {'name': 'being.human.s04.e09.too.far.fastforward.(2014).eng.1cd', 'chunk_index': 518}
# {'name': 'golden.kamuy.s02.e03.lets.talk.about.the.past.(2018).eng.1cd', 'chunk_index': 519}
# {'name': 'love.island.s08.e58.episode.58.().eng.1cd', 'chunk_index': 520}
# {'name': 'macherla.niyojakavargam.(2022).eng.1cd', 'chunk_index': 521}
# {'name': '24.s07.e07.day.7.200.p.m.300.p.m.(2009).eng.1cd', 'chunk_index': 522}
# {'name': 'yowamushi.pedal.s03.e11.conclusion.(2017).eng.1cd', 'chunk_index': 523}
# {'name': 'highlander.the.animated.series.s02.e11.lord.for.a.day.(1995).eng.1cd', 'chunk_index': 524}
# {'name': 'third.watch.s02.e09.run.of.the.mill.(2000).eng.1cd', 'chunk_index': 525}
# {'name': 'poker.face.s01.e06.exit.stage.death.(2023).eng.1cd', 'chunk_index': 526}
# {'name': 'castle.s06.e06.get.a.clue.(2013).eng.1cd', 'chunk_index': 527}
# {'name': 'suzuka.s01.e20.oen.(2005).eng.1cd', 'chunk_index': 528}
# {'name': 'quest.for.love.(2022).eng.1cd', 'chunk_index': 529}
# {'name': 'kamen.rider.black.sun.(2022).eng.1cd', 'chunk_index': 530}
# {'name': 'm3gan.(2022).eng.1cd', 'chunk_index': 531}
# {'name': 'pepsi.wheres.my.jet.s01.e02.lets.make.a.deal.(2022).eng.1cd', 'chunk_index': 532}
# {'name': 'i.met.my.murderer.online.s01.e10.julissa.(2021).eng.1cd', 'chunk_index': 533}
# {'name': 'roswell.s02.e15.viva.las.vegas.(2001).eng.1cd', 'chunk_index': 534}
# {'name': 'atomic.blonde.(2017).eng.1cd', 'chunk_index': 535}
# {'name': 'nova.s46.e02.einsteins.quantum.riddle.(2019).eng.1cd', 'chunk_index': 536}
# {'name': 'the.great.ecstasy.of.robert.carmichael.(2005).eng.1cd', 'chunk_index': 537}
# {'name': 'mila.in.the.multiverse.s01.e05.foge.(2023).eng.1cd', 'chunk_index': 538}
# {'name': 'the.amazing.race.canada.s07.e03.well.let.the.peasants.fight.for.last.place.(2019).eng.1cd', 'chunk_index': 539}
# {'name': 'doctor.who.s06.e13.the.wedding.of.river.song.(2011).eng.1cd', 'chunk_index': 540}
# {'name': 'war.of.the.worlds.s03.e05.episode.3.5.(2022).eng.1cd', 'chunk_index': 541}
# {'name': 'a.dragon.arrives.(2016).eng.1cd', 'chunk_index': 542}
# {'name': 'legend.of.the.seeker.s02.e03.broken.(2009).eng.1cd', 'chunk_index': 543}
# {'name': 'fate.the.winx.saga.s02.e03.your.newfound.popularity.().eng.1cd', 'chunk_index': 544}
# {'name': 'fired.on.mars.s01.e01.the.one.way.trip.(2023).eng.1cd', 'chunk_index': 545}
# {'name': 'safe.house.s02.e03.episode.2.3.(2017).eng.1cd', 'chunk_index': 546}
# {'name': 'the.blue.whisper.episode.1.2.().eng.1cd', 'chunk_index': 547}
# {'name': 'les.affaires.sont.les.affaires.(1942).eng.1cd', 'chunk_index': 548}
# {'name': 'love.flops.s01.e02.i.figure.we.all.have.our.own.pleasures.and.predilections.(2022).eng.1cd', 'chunk_index': 549}
# {'name': 'big.love.s01.e01.pilot.(2006).eng.1cd', 'chunk_index': 550}
# {'name': 'american.experience.s01.e02.radio.bikini.(1988).eng.1cd', 'chunk_index': 551}
# {'name': 'recess.s01.e06.to.finster.with.love.(1997).eng.1cd', 'chunk_index': 552}
# {'name': 'the.mindy.project.s04.e14.will.they.or.wont.they.(2016).eng.1cd', 'chunk_index': 553}
# {'name': 'shameless.s09.e07.down.like.the.titanic.(2018).eng.1cd', 'chunk_index': 554}
# {'name': 'the.flintstones.s01.e21.love.letters.on.the.rocks.(1961).eng.1cd', 'chunk_index': 555}
# {'name': '13.reasons.why.s01.e01.tape.1.side.a.(2017).eng.1cd', 'chunk_index': 556}
# {'name': 'may.i.help.you.s01.e04.the.guy.i.already.knew.(2022).eng.1cd', 'chunk_index': 557}
# {'name': 'nikita.s03.e04.consequences.(2012).eng.1cd', 'chunk_index': 558}
# {'name': 'tell.me.lies.s01.e10.the.bedrooms.of.our.friends.(2022).eng.1cd', 'chunk_index': 559}
# {'name': 'a.model.family.s01.e07.episode.1.7.(2022).eng.1cd', 'chunk_index': 560}
# {'name': 'im.totally.fine.(2022).eng.1cd', 'chunk_index': 561}
# {'name': 'de.la.guerre.(2008).eng.1cd', 'chunk_index': 562}
# {'name': 'bleach.(2018).eng.1cd', 'chunk_index': 563}
# {'name': 'martial.arts.of.shaolin.(1986).eng.1cd', 'chunk_index': 564}
# {'name': 'very.scary.people.s01.e07.aileen.wuornos.monster.made.part.1.(2019).eng.1cd', 'chunk_index': 565}
# {'name': 'oddballs.s02.e04.body.swap.(2023).eng.1cd', 'chunk_index': 566}
# {'name': 'family.guy.s06.e12.long.john.peter.(2008).eng.1cd', 'chunk_index': 567}
# {'name': 'yowamushi.pedal.s03.e04.the.fastest.man.on.minegayama.(2017).eng.1cd', 'chunk_index': 568}
# {'name': 'mussolini.the.untold.story.(1985).eng.1cd', 'chunk_index': 569}
# {'name': 'hot.in.cleveland.s03.e06.how.did.you.guys.meet.anyway.(2012).eng.1cd', 'chunk_index': 570}
# {'name': 'monster.s01.e32.sanctuary.(2004).eng.1cd', 'chunk_index': 571}
# {'name': 'riverdale.s07.e04.episode.7.4.().eng.1cd', 'chunk_index': 572}
# {'name': 'after.braveheart.(2015).eng.1cd', 'chunk_index': 573}
# {'name': 'simchas.and.sorrows.(2022).eng.1cd', 'chunk_index': 574}
# {'name': 'milf.manor.s01.e02.your.milf.should.know.(2023).eng.1cd', 'chunk_index': 575}
# {'name': 'paradise.highway.(2022).eng.1cd', 'chunk_index': 576}
# {'name': 'sacco.vanzetti.(1971).eng.1cd', 'chunk_index': 577}
# {'name': 'my.design.rules.s02.e17.whos.design.rules.(2020).eng.1cd', 'chunk_index': 578}
# ...
# {'name': 'to.be.someone.(2020).eng.1cd', 'chunk_index': 24562}
# {'name': 'beef.s01.e01.the.birds.dont.sing.they.screech.in.pain.(2023).eng.1cd', 'chunk_index': 24563}
# {'name': 'cat.(2022).eng.1cd', 'chunk_index': 24564}
# {'name': 'allo.allo.s05.e16.the.exploding.bedpan.(1988).eng.1cd', 'chunk_index': 24565}
# {'name': 'speak.no.evil.(2022).eng.1cd', 'chunk_index': 24566}
# {'name': 'so.help.me.todd.s01.e08.big.bang.theories.(2022).eng.1cd', 'chunk_index': 24567}
# {'name': '24.s06.e05.day.6.1000.a.m.1100.a.m.(2007).eng.1cd', 'chunk_index': 24568}
# {'name': 'home.movies.everybodys.entitled.to.my.opinion.().eng.1cd', 'chunk_index': 24569}
# {'name': 'cyberpunk.edgerunners.s01.e10.my.moon.my.man.(2022).eng.1cd', 'chunk_index': 24570}
# {'name': 'daughter.from.another.mother.s03.e02.a.celebration.of.love.(2022).eng.1cd', 'chunk_index': 24571}
# {'name': 'yowamushi.pedal.s04.e10.shinkai.yuto.(2018).eng.1cd', 'chunk_index': 24572}
# {'name': 'the.glades.s02.e02.old.ghosts.(2011).eng.1cd', 'chunk_index': 24573}
# {'name': 'do.it.yourself.s01.e04.diy.means.youll.find.it.possible.to.feel.comfortable.anywhere.(2022).eng.1cd', 'chunk_index': 24574}
# {'name': 'the.serpent.queen.s01.e07.an.attack.on.the.king.().eng.1cd', 'chunk_index': 24575}
# {'name': '65.(2023).eng.1cd', 'chunk_index': 24576}
# {'name': 'zeroman.s01.e10.les.than.zero.(2004).eng.1cd', 'chunk_index': 24577}
# {'name': 'the.expendables.3.(2014).eng.1cd', 'chunk_index': 24578}
# {'name': 'ghosts.s02.e02.albertas.podcast.(2022).eng.1cd', 'chunk_index': 24579}
# {'name': 'bake.squad.s01.e02.rock.n.roll.wedding.(2021).eng.1cd', 'chunk_index': 24580}
# {'name': 'holly.and.the.hot.chocolate.(2022).eng.1cd', 'chunk_index': 24581}
# {'name': 'northern.exposure.s05.e08.heal.thyself.(1993).eng.1cd', 'chunk_index': 24582}
# {'name': 'master.of.light.(2022).eng.1cd', 'chunk_index': 24583}
# {'name': 'fantasy.island.s02.e03.paymer.vs.paymer.(2023).eng.1cd', 'chunk_index': 24584}
# {'name': 'supercar.s02.e03.operation.superstork.(1962).eng.1cd', 'chunk_index': 24585}
# {'name': 'remember.me.the.mahalia.jackson.story.(2022).eng.1cd', 'chunk_index': 24586}
# {'name': 'king.of.the.hill.s11.e07.the.passion.of.the.dauterive.(2007).eng.1cd', 'chunk_index': 24587}
# {'name': 'they.crawl.beneath.(2022).eng.1cd', 'chunk_index': 24588}
# {'name': 'manayek.s01.e06.hodim.(turkeys).(2020).eng.1cd', 'chunk_index': 24589}
# {'name': 'outlander.s06.e08.i.am.not.alone.(2022).eng.1cd', 'chunk_index': 24590}
# {'name': 'csi.miami.s04.e07.felony.flight.(2005).eng.1cd', 'chunk_index': 24591}
# {'name': 'nikita.s04.e06.canceled.(2013).eng.1cd', 'chunk_index': 24592}
# {'name': 'stalingrad.(2013).eng.1cd', 'chunk_index': 24593}
# {'name': 'chasing.waves.s01.e02.weight.of.a.nation.(2023).eng.1cd', 'chunk_index': 24594}
# {'name': 'wag.mong.agawin.ang.akin.s01.e06.ganti.ng.inagawan.(2022).eng.1cd', 'chunk_index': 24595}
# {'name': 'tales.of.wells.fargo.s05.e15.border.renegades.(1961).eng.1cd', 'chunk_index': 24596}
# {'name': 'family.guy.s13.e14.jolo.(2015).eng.1cd', 'chunk_index': 24597}
# {'name': 'ghosts.s02.e07.the.ghost.of.christmas.(2020).eng.1cd', 'chunk_index': 24598}
# {'name': 'chappelles.show.s01.e05.great.moments.in.hookup.history.ask.a.black.dude.(2003).eng.1cd', 'chunk_index': 24599}
# {'name': 'the.munsters.s02.e02.herman.the.master.spy.(1965).eng.1cd', 'chunk_index': 24600}
# {'name': 'wutang.an.american.saga.s03.e01.i.cant.go.to.sleep.(2023).eng.1cd', 'chunk_index': 24601}
# {'name': 'britains.most.evil.killers.s04.e09.peter.moore.(2020).eng.1cd', 'chunk_index': 24602}
# {'name': 'the.green.glove.gang.s01.e04.episode.1.4.(2022).eng.1cd', 'chunk_index': 24603}
# {'name': 'medium.s06.e04.the.medium.is.the.message.(2009).eng.1cd', 'chunk_index': 24604}
# {'name': 'single.drunk.female.s02.e03.normie.().eng.1cd', 'chunk_index': 24605}
# {'name': 'the.challenge.argentina.el.desafio.s01.e05.episode.1.5.(2023).eng.1cd', 'chunk_index': 24606}
# {'name': 'jodha.akbar.s01.e309.episode.1.309.(2014).eng.1cd', 'chunk_index': 24607}
# {'name': 'young.lady.and.gentleman.s01.e17.episode.1.17.(2021).eng.1cd', 'chunk_index': 24608}
# {'name': 'bridge.of.the.doomed.(2022).eng.1cd', 'chunk_index': 24609}
# {'name': 'upstairs.downstairs.s02.e10.a.special.mischief.(1972).eng.1cd', 'chunk_index': 24610}
# {'name': 'friends.s07.e15.the.one.with.joeys.new.brain.(2001).eng.1cd', 'chunk_index': 24611}
# {'name': 'preacher.s01.e08.el.valero.(2016).eng.1cd', 'chunk_index': 24612}
# {'name': 'beverly.hills.90210.s03.e14.wild.horses.(1992).eng.1cd', 'chunk_index': 24613}
# {'name': 'dracula.(1974).eng.1cd', 'chunk_index': 24614}
# {'name': 'crayon.shinchan.shrouded.in.mystery.the.flowers.of.tenkazu.academy.(2021).eng.1cd', 'chunk_index': 24615}
# {'name': 'secrets.of.the.oligarch.wives.(2022).eng.1cd', 'chunk_index': 24616}
# {'name': 'endless.love.s01.e29.episode.1.29.(2016).eng.1cd', 'chunk_index': 24617}
# {'name': 'wednesday.s01.e07.if.you.dont.woe.me.by.now.(2022).eng.1cd', 'chunk_index': 24618}
# {'name': 'river.monsters.s03.e05.electric.executioner.(2011).eng.1cd', 'chunk_index': 24619}
# {'name': 'the.walking.dead.s11.e18.a.new.deal.(2022).eng.1cd', 'chunk_index': 24620}
# {'name': 'bob.hearts.abishola.s04.e01.touched.by.a.holy.hand.(2022).eng.1cd', 'chunk_index': 24621}
# {'name': 'csi.ny.s02.e20.run.silent.run.deep.(2006).eng.1cd', 'chunk_index': 24622}
# {'name': 'full.house.s01.e01.episode.1.1.(2004).eng.1cd', 'chunk_index': 24623}
# {'name': 'five.days.at.memorial.s01.e06.45.dead.(2022).eng.1cd', 'chunk_index': 24624}
# {'name': 'alias.s01.e15.page.47.(2002).eng.1cd', 'chunk_index': 24625}
# {'name': 'southwest.of.salem.the.story.of.the.san.antonio.four.(2016).eng.1cd', 'chunk_index': 24626}
# {'name': 'dam.s02.e03.impregnation.(2023).eng.1cd', 'chunk_index': 24627}
# {'name': 'game.changer.s04.e09.survivor.part.1.(2022).eng.1cd', 'chunk_index': 24628}
# {'name': 'shameless.s02.e09.hurricane.monica.(2012).eng.1cd', 'chunk_index': 24629}
# {'name': 'halifax.retribution.s01.e01.episode.1.1.(2020).eng.1cd', 'chunk_index': 24630}
# {'name': 'futurama.s02.e18.the.problem.with.popplers.(2000).eng.1cd', 'chunk_index': 24631}
# {'name': 'silent.land.(2021).eng.1cd', 'chunk_index': 24632}
# {'name': 'tar.(2022).eng.1cd', 'chunk_index': 24633}
# {'name': 'csi.crime.scene.investigation.s06.e19.spellbound.(2006).eng.1cd', 'chunk_index': 24634}
# {'name': 'medium.s03.e06.profiles.in.terror.(2006).eng.1cd', 'chunk_index': 24635}
# {'name': 'the.jeffersons.s09.e14.my.maid.my.wife.(1983).eng.1cd', 'chunk_index': 24636}
# {'name': 'jane.s01.e05.gavialis.gangeticus.().eng.1cd', 'chunk_index': 24637}
# {'name': 'alfred.hitchcock.presents.s03.e04.heart.of.gold.(1957).eng.1cd', 'chunk_index': 24638}
# {'name': 'all.american.homecoming.s02.e12.behind.the.mask.(2023).eng.1cd', 'chunk_index': 24639}
# {'name': 'the.magnificent.seven.s02.e06.wagon.train.part.2.(1999).eng.1cd', 'chunk_index': 24640}
# {'name': 'were.here.s03.e01.granbury.texas.(2022).eng.1cd', 'chunk_index': 24641}
# {'name': 'the.killer.(2022).eng.1cd', 'chunk_index': 24642}
# {'name': 'younger.s04.e09.the.incident.at.pound.ridge.(2017).eng.1cd', 'chunk_index': 24643}
# {'name': 'welcome.to.eden.s02.e05.episode.2.5.(2023).eng.1cd', 'chunk_index': 24644}
# {'name': 'scrubs.s06.e08.my.road.to.nowhere.(2007).eng.1cd', 'chunk_index': 24645}
# {'name': 'unbreakable.kimmy.schmidt.s04.e02.kimmy.has.a.weekend.(2018).eng.1cd', 'chunk_index': 24646}
# {'name': 'inspectre.s02.e05.rikka.returns.(2023).eng.1cd', 'chunk_index': 24647}
# {'name': 'once.upon.a.time.s03.e15.quiet.minds.(2014).eng.1cd', 'chunk_index': 24648}
# {'name': 'the.fourth.protocol.(1987).eng.1cd', 'chunk_index': 24649}
# {'name': 'teen.wolf.s01.e03.pack.mentality.(2011).eng.1cd', 'chunk_index': 24650}
# {'name': 'fortune.feimster.good.fortune.(2022).eng.1cd', 'chunk_index': 24651}
# {'name': 'sound.of.violence.(2021).eng.1cd', 'chunk_index': 24652}
# {'name': 'jojos.bizarre.adventure.s05.e29.netherworld.().eng.1cd', 'chunk_index': 24653}
# {'name': 'gossip.girl.s03.e15.the.sixteen.year.old.virgin.(2010).eng.1cd', 'chunk_index': 24654}
# {'name': 'destination.mars.s01.e04.surviving.on.mars.(2015).eng.1cd', 'chunk_index': 24655}
# {'name': 'catch.the.ghost.s01.e01.subways.transporting.ghosts.(2019).eng.1cd', 'chunk_index': 24656}
# {'name': 'bronx.siu.s01.e07.meet.jimmy.blue.(2018).eng.1cd', 'chunk_index': 24657}
# {'name': 'night.of.the.tommyknockers.(2022).eng.1cd', 'chunk_index': 24658}
# {'name': 'power.book.iii.raising.kanan.s02.e06.its.a.business.man.(2022).eng.1cd', 'chunk_index': 24659}
# {'name': 'my.fathers.shadow.the.sam.sheppard.story.(1998).eng.1cd', 'chunk_index': 24660}
# {'name': 'king.of.the.hill.s11.e03.blood.and.sauce.(2007).eng.1cd', 'chunk_index': 24661}
# {'name': '24.s03.e13.day.3.100.a.m.200.a.m.(2004).eng.1cd', 'chunk_index': 24662}
# {'name': 'ncis.s05.e04.identity.crisis.(2007).eng.1cd', 'chunk_index': 24663}
# {'name': 'atlanta.s04.e09.andrew.wyeth.alfreds.world.(2022).eng.1cd', 'chunk_index': 24664}
# {'name': 'the.goldbergs.s10.e05.uncleing.(2022).eng.1cd', 'chunk_index': 24665}
# {'name': 'taskmaster.s14.e05.chip.biffington.(2022).eng.1cd', 'chunk_index': 24666}
# {'name': 'taskmaster.s14.e09.a.new.business.end.(2022).eng.1cd', 'chunk_index': 24667}
# {'name': 'heroes.s01.e17.chapter.seventeen.company.man.(2007).eng.1cd', 'chunk_index': 24668}
# {'name': 'northern.exposure.s01.e06.sex.lies.and.eds.tapes.(1990).eng.1cd', 'chunk_index': 24669}
# {'name': 'family.nest.(1979).eng.1cd', 'chunk_index': 24670}
# {'name': 'the.restaurant.s03.e07.nedrakningen.(2019).eng.1cd', 'chunk_index': 24671}
# {'name': 'american.dad.s11.e13.widows.pique.(2016).eng.1cd', 'chunk_index': 24672}
# {'name': 'wild.youth.(1960).eng.1cd', 'chunk_index': 24673}
# {'name': 'heroes.s03.e08.chapter.eight.villains.(2008).eng.1cd', 'chunk_index': 24674}
# {'name': 'sokado.ggumgyeol.s01.e47.episode.1.47.(2021).eng.1cd', 'chunk_index': 24675}
# {'name': 'doctor.who.s21.e12.resurrection.of.the.daleks.part.two.(1984).eng.1cd', 'chunk_index': 24676}
# {'name': 'desperate.housewives.s08.e13.is.this.what.you.call.love.(2012).eng.1cd', 'chunk_index': 24677}
# {'name': 'who.were.we.running.from.s01.e07.episode.1.7.(2023).eng.1cd', 'chunk_index': 24678}
# {'name': 'fruits.basket.s03.e08.im.disappointed.in.you.(2021).eng.1cd', 'chunk_index': 24679}
# {'name': 'dae.wang.sejong.s01.e60.episode.1.60.(2008).eng.1cd', 'chunk_index': 24680}
# {'name': 'baahubali.the.beginning.(2015).eng.1cd', 'chunk_index': 24681}
# {'name': 'zero.fks.(2020).eng.1cd', 'chunk_index': 24682}
# {'name': 'grand.exit.(1935).eng.1cd', 'chunk_index': 24683}
# {'name': 'walker.independence.s01.e07.the.owl.and.the.arrow.(2022).eng.1cd', 'chunk_index': 24684}
# {'name': 'ejen.ali.s02.e11.misi.harapan.(2018).eng.1cd', 'chunk_index': 24685}
# {'name': 'notredame.s01.e03.episode.1.3.(2022).eng.1cd', 'chunk_index': 24686}
# {'name': 'the.americans.s04.e10.munchkins.(2016).eng.1cd', 'chunk_index': 24687}
# {'name': 'reasonable.doubt.s01.e03.99.problems.(2022).eng.1cd', 'chunk_index': 24688}
# {'name': 'murder.in.successville.s03.e03.i.saw.a.monster.(2017).eng.1cd', 'chunk_index': 24689}
# {'name': 'charmed.s07.e01.a.call.to.arms.(2004).eng.1cd', 'chunk_index': 24690}
# {'name': 'catherine.called.birdy.(2022).eng.1cd', 'chunk_index': 24691}
# {'name': 'keeping.up.with.the.kardashians.s13.e11.classic.cars.and.vintage.eggs.(2017).eng.1cd', 'chunk_index': 24692}
# {'name': 'american.horror.story.s11.e07.the.sentinel.(2022).eng.1cd', 'chunk_index': 24693}
# {'name': 'the.ateam.s04.e07.body.slam.(1985).eng.1cd', 'chunk_index': 24694}
# {'name': 'csi.miami.s08.e01.out.of.time.(2009).eng.1cd', 'chunk_index': 24695}
# {'name': 'def.comedy.jam.s01.e05.episode.1.5.(1992).eng.1cd', 'chunk_index': 24696}
# {'name': 'daeng.phra.khanong.(2022).eng.1cd', 'chunk_index': 24697}
# {'name': 'matty.hanson.and.the.invisibility.ray.(2011).eng.1cd', 'chunk_index': 24698}
# {'name': 'alchemy.of.souls.s01.e16.episode.1.16.(2022).eng.1cd', 'chunk_index': 24699}
# {'name': 'i.am.a.killer.s01.e04.sympathy.for.the.devil.(2018).eng.1cd', 'chunk_index': 24700}
# {'name': 'swarm.s01.e03.taste.(2023).eng.1cd', 'chunk_index': 24701}
# {'name': 'after.she.died.(2022).eng.1cd', 'chunk_index': 24702}
# {'name': 'the.makanai.cooking.for.the.maiko.house.s01.e07.illness.(2023).eng.1cd', 'chunk_index': 24703}
# {'name': 'thicker.than.water.s01.e07.the.bargaining.chip.(2023).eng.1cd', 'chunk_index': 24704}
# {'name': 'high.society.s01.e06.episode.1.6.(2015).eng.1cd', 'chunk_index': 24705}
# {'name': 'the.one.in.charge.s01.e05.visita.sorpresa.(2022).eng.1cd', 'chunk_index': 24706}
# {'name': 'dungeons.dragons.the.book.of.vile.darkness.(2012).eng.1cd', 'chunk_index': 24707}
# {'name': 'murdoch.mysteries.s12.e16.manual.for.murder.(2019).eng.1cd', 'chunk_index': 24708}
# {'name': 'diary.of.a.gigolo.s01.e07.episode.1.7.(2022).eng.1cd', 'chunk_index': 24709}
# {'name': 'beauty.and.the.beast.s03.e02.primal.fear.(2015).eng.1cd', 'chunk_index': 24710}
# {'name': 'masters.of.sex.s01.e06.brave.new.world.(2013).eng.1cd', 'chunk_index': 24711}
# {'name': 'khaleja.(2010).eng.1cd', 'chunk_index': 24712}
# {'name': 'beauty.and.the.beast.s03.e09.cats.out.of.the.bag.(2015).eng.1cd', 'chunk_index': 24713}
# {'name': '16.to.life.(2009).eng.1cd', 'chunk_index': 24714}
# {'name': 'ancient.unexplained.files.s01.e08.tomb.of.the.red.queen.(2021).eng.1cd', 'chunk_index': 24715}
# {'name': 'three.tall.women.(2022).eng.1cd', 'chunk_index': 24716}
# {'name': 'knots.landing.s02.e10.choices.(1981).eng.1cd', 'chunk_index': 24717}
# {'name': 'archie.bunkers.place.s03.e08.growing.up.is.hard.to.do.part.1.(1981).eng.1cd', 'chunk_index': 24718}
# {'name': 'hua.jai.sila.s01.e04.episode.1.4.(2019).eng.1cd', 'chunk_index': 24719}
# {'name': 'married.with.children.s05.e24.route.666.part.2.(1991).eng.1cd', 'chunk_index': 24720}
# {'name': 'sapphire.steel.s03.e02.assignment.five.part.2.(1981).eng.1cd', 'chunk_index': 24721}
# {'name': 'super.giant.robot.brothers.s01.e02.welcome.to.g.r.i.t.s.(2022).eng.1cd', 'chunk_index': 24722}
# {'name': 'madam.secretary.s04.e05.persona.non.grata.(2017).eng.1cd', 'chunk_index': 24723}
# {'name': 'sisters.s01.e05.episode.1.5.(2023).eng.1cd', 'chunk_index': 24724}
# {'name': 'red.dust.(1932).eng.1cd', 'chunk_index': 24725}
# {'name': 'accused.s01.e06.naataaniis.story.().eng.1cd', 'chunk_index': 24726}
# {'name': 'beverly.hills.90210.s03.e04.sex.lies.and.volleyballphoto.fini.(1992).eng.1cd', 'chunk_index': 24727}
# {'name': 'que.tan.lejos.(2006).eng.1cd', 'chunk_index': 24728}
# {'name': 'the.owl.house.s03.e01.thanks.to.them.(2022).eng.1cd', 'chunk_index': 24729}
# {'name': 'resident.evil.apocalypse.(2004).eng.1cd', 'chunk_index': 24730}
# {'name': 'chicago.justice.s01.e01.fake.(2017).eng.1cd', 'chunk_index': 24731}
# {'name': 'the.jayhawkers.(1959).eng.1cd', 'chunk_index': 24732}
# {'name': 'scorpion.s03.e13.faux.money.maux.problems.(2017).eng.1cd', 'chunk_index': 24733}
# {'name': 'susah.sinyal.the.series.s01.e02.coba.narsis.buat.eksis.(2021).eng.1cd', 'chunk_index': 24734}
# {'name': 'rap.sht.s01.e07.something.for.the.dj.(2022).eng.1cd', 'chunk_index': 24735}
# {'name': 'odnazhdy.v.pustyne.(2022).eng.1cd', 'chunk_index': 24736}
# {'name': 'pretty.hard.cases.s03.e01.always.a.bridesmaid.(2023).eng.1cd', 'chunk_index': 24737}
# {'name': 'the.walking.dead.s11.e22.faith.(2022).eng.1cd', 'chunk_index': 24738}
# {'name': 'secrets.of.the.dead.s19.e05.a.samurai.in.the.vatican.(2021).eng.1cd', 'chunk_index': 24739}
# {'name': 'titans.of.the.20th.century.s01.e04.darkest.hour.19371940.(2020).eng.1cd', 'chunk_index': 24740}
# {'name': 'the.jeffersons.s10.e09.whos.the.fairest.(1983).eng.1cd', 'chunk_index': 24741}
# {'name': 'the.man.who.had.power.over.women.(1970).eng.1cd', 'chunk_index': 24742}
# {'name': 'shape.island.s01.e03.triangle.gets.carried.awaysquares.different.day.(2023).eng.1cd', 'chunk_index': 24743}
# {'name': 'kevin.can.wait.s01.e13.ring.worm.(2017).eng.1cd', 'chunk_index': 24744}
# {'name': 'bia.s01.e29.episode.1.29.(2019).eng.1cd', 'chunk_index': 24745}
# {'name': 'heroes.s02.e11.chapter.eleven.powerless.(2007).eng.1cd', 'chunk_index': 24746}
# {'name': 'hot.in.cleveland.s05.e09.bad.george.clooney.(2014).eng.1cd', 'chunk_index': 24747}
# {'name': 'silk.stalkings.s04.e18.i.know.what.scares.you.(1995).eng.1cd', 'chunk_index': 24748}

# %%
ids
# Out:
# ['ee83d0b3-aef9-4961-a486-5c13f9423ca6',
#  '8097ccc9-d300-4c25-b962-b0f1109603e9',
#  '4b4ac296-617d-4000-ba66-1b18d538c24b',
#  'e4e75b55-7225-422b-ae94-db8fd8c34350',
#  'f7f6825e-93a4-4bba-805e-8be7e4bb2b78',
#  'a45c0ee8-64dc-49ac-85df-6451209578ff',
#  '15291fa6-f79a-4e69-b425-a1bf0e0845a2',
#  'd27fe0d5-6fb0-4ee1-8e18-238afd335a55',
#  'c22bdf3d-55f9-4248-aaa1-4f220c5c6580',
#  '15692559-3e2c-4973-8eda-be24eb3998ee',
#  'e9c4a285-3746-4f91-b736-69348292efb8',
#  'e59d18fb-6966-4743-a0aa-442203b25ec9',
#  '3b7002ef-7bc3-4d09-a0d7-9c68458c4d59',
#  '45ac1be0-2ff5-4b62-8d50-a0dfc298c7ad',
#  'cc66d8c4-9d6d-42ad-aa96-f838e951af03',
#  '27671bc5-4401-402d-9447-2fd9227181b4',
#  '7aaacb34-9bb6-44ad-9646-43d63734dbfd',
#  '928601c6-0a3c-470d-b804-efc75898224f',
#  '4f98bc48-1f03-466c-a345-e9e98a88c5ef',
#  'a44a9b7e-2893-456b-b066-ec0b955f3d83',
#  '0c216902-2a4b-4b6d-8790-de4d56dac371',
#  'f55ff564-c40f-49d9-945c-cc2cee1e6b65',
#  'c822078f-e448-47f2-bc86-13ecdfe235c6',
#  '0913e824-8277-47d4-83b5-855eecbede2f',
#  '40ad9f5d-7a84-40d5-91d7-69affeea63e3',
#  '59950f44-5051-43b4-9864-5f0eda079aff',
#  'b0a24522-28d4-4548-a8c2-8848d63d70e4',
#  '3e6975ed-e881-4028-b562-e4583e75a292',
#  '3dbdf415-acaf-4dca-b882-9b6fe4afec9e',
#  'd473d42b-db71-4ae2-b361-2dd82d529bbc',
#  'cb9e739c-d32b-4fa4-973b-49be1ad12873',
#  '10710aab-5326-486b-baaf-9ae8122ec9b0',
#  '02dba817-8599-436c-ad5b-b239cbc3c003',
#  '65d08800-714e-4b7f-8f96-ee3fb88f4f43',
#  'b1f356ce-5444-4d9c-87d0-d6d52bc8e482',
#  'ffe208f7-a8bd-461d-a699-7139aa9e0ac3',
#  'bddb698d-30aa-49a6-bfce-f88d211f0e57',
#  '3a3c81e8-7110-4d50-bc27-b839f0ad564f',
#  '8627147b-dd84-4f85-b4cb-2ccd1e38ba6e',
#  'a11748e8-67e5-4f14-a5e8-70873193a1e5',
#  '188e0d82-d997-4a12-b767-221b76d0b999',
#  '970e9e5b-f880-4b56-adec-0c030d351828',
#  'afc79ec1-0784-46ad-92c2-c307cc708aa1',
#  '72c5ee5e-2801-4e73-b72d-09ee02d9410f',
#  '5bcfc427-bae5-49d6-8f7d-da0d020e5853',
#  'baf4f5c5-4888-4362-807b-f6a60ff10c67',
#  'b15a15ce-f502-46c8-a8c7-437a9db7f7ab',
#  '005c52be-8906-4644-8b96-0b821cc0fd2d',
#  '82b03fdd-d18e-472a-aa91-68d3aafb2764',
#  '1bad17ab-e76a-49b4-ac7e-b977098c7916',
#  'bbf082d3-37df-4d33-b95f-b5e53cb43f2d',
#  '80fd394a-8125-43f1-bb9c-c64a2191eedc',
#  'a7496742-856f-4e52-8ed1-d534c13583c4',
#  'df1f600e-9485-439e-a6c8-724b9032870e',
#  'a8c36170-e583-4640-8012-82c61eeeb6a0',
#  'e287a6d9-56b8-4394-bed8-f1d3581d8129',
#  'dfc27b8b-2251-49f5-a46a-17fad2059c8c',
#  '8edc1bd6-2d4c-4fa6-902d-1546f0f0a638',
#  '6822a9a3-d9bb-412c-afbb-a1bb085bedcb',
#  '0cada532-8b9b-4ed3-998f-5e9ea75fc4bb',
#  '88e246a0-9217-4e42-bb4d-4c70f395ee1e',
#  '863dc439-adba-4431-a3ca-14ee70085993',
#  '4c8c3890-7896-46f0-865e-102226b7701d',
#  'be1dbb11-297c-4920-a3cd-16cd20735f89',
#  '110e5143-0796-4778-bb1d-e7ef305962c6',
#  '7705a617-105d-4067-bfc1-df41da375e44',
#  'c90314ec-3bc2-4d30-837f-42d692788808',
#  '73a5dfea-98c2-413f-9df6-14cd169ca6d0',
#  'b6cea88f-9e99-488f-b338-b0b669aaaccd',
#  'd75a059e-dc29-4fa4-9e88-859302cd6066',
#  '3c74333d-9eb2-4f4f-a544-f62bccc3803e',
#  'bf3358fd-0d73-42c0-86d5-6f83f6ffa8a0',
#  'c03f7314-6606-4cb6-84fb-2e3f65f0af4f',
#  '72d45aae-c3b8-40fe-8b7f-0ae094e3443f',
#  'cdcfaeb9-9e61-4716-8732-aa167efe6af2',
#  '4ba3852b-7026-41e6-9aea-0d97b2e373c2',
#  'fd9ddf4f-7088-4423-a4ef-e343afb7eb5c',
#  'e3b7a4ee-9c41-4759-a84c-694529af0578',
#  'ca1336bc-ff11-4ce1-af89-fa2f206cbc59',
#  '3f2cd497-16ea-4552-9425-950acf2c81c7',
#  '484321f0-1b6a-4756-ac74-1863d5dbe200',
#  'dbe51f4b-6772-491c-a2c5-ccd32d11fbd9',
#  '1a102a04-0ef6-43e7-9bda-551aac05369e',
#  '2c4be8c4-d035-4d0b-a85b-7f96da288c86',
#  '58969706-8a9e-4280-97ec-553d4714f601',
#  '23fe425a-d9fb-4006-bd79-56787990c0ef',
#  '669d34cd-cd8e-43ab-90fb-4d7f2eb5cff6',
#  '9161f4b6-d733-4b2a-9071-c4398a067b38',
#  '2e21fc4e-c010-495c-a881-fd3b8320f78a',
#  '41b11fa0-5ec7-4201-adb2-631ea4163e3e',
#  '79b4e89e-7a85-4baf-b662-eda34b0f7d86',
#  'b397e815-d9c4-47ff-bb45-5617ee938928',
#  '659d41d9-4fd2-4208-945d-0358f5a2154a',
#  'a950ac9a-887b-4ac5-a9b9-99c548139beb',
#  '23b27c8d-45bb-418a-b7cc-5729e831d331',
#  '8ccea8e4-9a3e-4c9f-8d77-550a7c9d51a5',
#  '39035cfa-52ae-4177-894a-37e338e14aa5',
#  '2b06eb89-8835-4cef-baa9-5c79dbb27a77',
#  '04de780b-4a42-4cfe-abe7-56966cbdd52e',
#  '4ceed9e4-6121-47ab-99b8-0b63d1edd0e6',
#  'c54bdeee-62d5-480d-aed9-b6b0f2ed94d3',
#  '0a7319b4-9a12-4573-b53e-5d3a51461bf4',
#  '83284fb5-d888-47fa-9e38-ed02afe54449',
#  'a656a748-19b5-4691-9d24-c8d621ddbb9c',
#  '4e64f85a-bc3c-4792-9931-0663177e9bf1',
#  'a010e0c7-e0bc-4641-8334-80241d2a4f60',
#  '8c26b048-64fa-403a-bad7-d19779e6cc35',
#  '816a73e3-12c4-450d-8dae-8905e54f9041',
#  '4b1316a5-dc5e-4eb3-9e91-250896e3537b',
#  'ed626d7d-748a-4b45-bb1b-867c8e34756d',
#  '21f9a85c-d9b3-4bc9-91d1-163103c288f2',
#  'dd7a2c2d-5a75-4c7a-bedd-ed3d3c1ec8dd',
#  '1baa6244-42ab-489e-b6d6-7affe0accf50',
#  '6f0b4e35-ca97-413b-ae98-c52bd3ec1cf7',
#  'b0299ffe-5d51-48ea-a0a6-79d6179cce2d',
#  '225139ac-6780-47ae-85bb-449c95768a03',
#  '47c664ec-e616-45f9-8145-6425f0771846',
#  '6d4149f9-927a-4c49-a57e-43ef0fcbe49b',
#  '4ec81435-1211-462b-8e9d-235d1deaf0d7',
#  '475b5a61-0d37-4601-a741-a53034bbf2f6',
#  '49aef6fe-bf1f-4149-991e-0d13040d3f1e',
#  'f397a8e8-ed2d-46d4-bc55-ad16009b0faf',
#  'a7a3f9d2-7825-4cfb-ba66-8884aab34b42',
#  'c2c60af3-4603-4101-bc03-b8c9cd9ec567',
#  'bbfeebd2-e08e-4d1e-8c37-81fbe258c042',
#  '3979383f-f8e6-4187-9241-ea9472f8976e',
#  '0f09ab9e-0d89-44c4-92c7-f4c32643348e',
#  '7e1e7e71-14ce-493a-9b90-36ddeda747cc',
#  '65b1939e-edf4-4be6-afa2-21778400df4b',
#  '9d548378-631b-424a-920f-408ef2713401',
#  '1a62572e-246d-4afd-9ff0-4e9cc8949a67',
#  '7b01aab7-8d77-4b95-aab7-3766670b64a1',
#  '7e6f5b3f-8a05-438b-8599-19243e459fb8',
#  'da687f70-0a3d-402c-b6d0-da7c8b5dd911',
#  '23371312-9ce5-4538-89d1-a0c4c884b6dc',
#  '894c3750-b098-418b-8951-44ac68af9eea',
#  '3d99d1a7-549d-428f-9ed2-50a853d8ff55',
#  'd936f628-3e75-4312-afaf-77aa4fb8c764',
#  'a188ec38-fd00-4df0-a2db-b8239b79a65d',
#  'fce2d9a4-5947-4beb-89b4-141a3b595599',
#  'acc349e1-bf4d-4cf3-9121-50462ad290fb',
#  'ddcdbc55-161d-428b-b8ec-d37d7f957603',
#  '5013abbe-9b27-4ec6-bd2b-d280bab7168b',
#  '6159b043-76f2-4cac-80c1-6650d129fc34',
#  'f38e557e-11fd-4b60-a5ff-57ecc1073e3a',
#  '5b3d470c-ddc7-4b4b-ad09-643dbcaee73e',
#  'ca33ed90-803f-44d6-bc25-a26e1b610710',
#  '5decc024-4a14-40ec-9fe6-855c26e9d965',
#  '30c13b1f-f57f-43b7-aa5f-9b4319714d84',
#  '9eef850a-b69a-4f81-b817-e89db6e1e715',
#  '830dff65-b0de-47fa-8156-be82a21f8712',
#  '4e7aee14-6e1e-43c2-89f0-53d7fd8937f1',
#  '7f0fdec7-93d0-4cb6-b0c6-2f98573235e3',
#  '5411028e-92fc-43ef-8400-b08d9e0381a4',
#  '0528ffde-86b7-4550-91c9-297717833254',
#  'f14edbb8-7370-4004-8f36-e5b9fcea0dcb',
#  '02604466-bfd7-42f8-b454-fe4953e928e4',
#  '1734401b-3350-41b5-8a35-29d7ca9b462f',
#  '84d5a529-091c-4635-8fc3-10c30220764f',
#  '2016b2dd-3257-4801-aae1-b7a7c17df164',
#  '661632e1-f826-4bb7-b7f3-38a46cdbc94e',
#  '5f5fd69a-4ed1-4378-8eb0-87f7cb3e84ff',
#  'a2ed0dfa-ccde-40c4-9486-74c93cadff03',
#  '535d06d8-6a5a-4bcd-9133-d6da1ba53c5a',
#  '274ed109-2895-4230-b8dd-3f44a140d7cd',
#  '625191eb-9a35-45da-84a7-6563b73f6389',
#  '8ebc5cda-dfd6-41f0-b42c-d6f79d6dc746',
#  '46b667a0-078b-499c-b026-2e49a432b8d8',
#  '0d392abc-4cb7-4da7-a514-112f881e89fe',
#  'c1470960-a5d5-48c9-9e5f-13a5c0ac2514',
#  '9ede2459-72f6-4db6-978b-3f174e0e5de7',
#  'ed1ded35-12ed-41c2-8d0e-75a146f1ec11',
#  '0b7448ae-6fb4-49e2-9821-443e4c2fb00e',
#  '947114e3-4d9f-436a-a0fd-440ac9d56d0e',
#  '2904b830-a90a-4b1a-a2e9-8930b7c367f3',
#  'a6416c70-7145-485d-a202-34991a00a9d9',
#  '4dd630a9-8ddd-449f-9ea2-0a85106f2cb6',
#  'e9bfe9b8-2645-4843-a203-6ba16b3a5885',
#  'bca658f7-2f96-4267-bccb-18ed332e5b59',
#  'c1f5a0bd-ca06-4b2f-8bb1-b64b488e1c35',
#  'd7e0aa5c-fc65-4f40-980b-b99251bc450c',
#  '5e8533c1-4ba3-42ce-899c-79efc9a28676',
#  'fde47f5c-5865-49c4-b555-2a7946e02b38',
#  '54c9fd14-02df-4026-b90f-893f25b4764e',
#  'c6f095b3-b15b-4a48-9cd9-6feafa2d1111',
#  '35bb5dd4-4ea9-4819-b532-4d5869efbdc3',
#  '47d60f4a-fac0-47d2-81f6-c789da7d85b9',
#  'bf7144d2-d1ed-4f02-91c1-41dfc636da86',
#  '9049b47c-afd4-4e11-b78a-f8d7d604f8af',
#  '4d456b62-8857-4d12-83b9-9f51abecf948',
#  'b8f7325b-123c-4505-b9e1-3022cf7549e9',
#  '481acb7a-4a41-4c13-9202-71609fb6d53c',
#  '2adf8037-554c-433f-b8b4-09607bbd13a4',
#  '0834e2eb-8403-454b-91ad-07cd8b3294d6',
#  '159e4e8d-3396-4b38-a9c7-f39a5e11b94b',
#  'fcfd6111-038d-4482-b27b-863524b55a8d',
#  'ed7b3721-4301-4366-99e0-97f58e7db16f',
#  '3d83aee1-4527-40ea-87a2-815acd6ccc4a',
#  '88e2c803-33bc-4965-b6b8-bbaf892a22d9',
#  'bc131d93-e1bd-4b3c-a9e2-37df71e1bb50',
#  'ce405608-cfdf-4a36-b600-24222e0f3b02',
#  '18f2a532-491d-4c41-aa85-7da5778eb37a',
#  'd435c1cf-440f-4f10-86be-e8efb1bc2c35',
#  'eb65dac9-1450-4724-bda7-c7c00f687989',
#  'f695ee7b-9cc6-45f3-9b1b-6377a4e88a54',
#  '7779e0c2-f439-4418-b9ca-5f0ef37934f5',
#  'fb2ea724-08da-497f-b2cc-9f0c40b40c43',
#  'c565fb62-8d41-4f60-a048-4488732fd5b2',
#  '8f0bd430-42e7-4d85-836a-bcb4742953f7',
#  '18fc8651-c214-4971-9ae2-1fa078ec1252',
#  '9cdce26c-b5c7-4526-abbd-e70e70858bfc',
#  '95d864bd-ff2e-4dd5-97fc-6af402e1279b',
#  'eb738b3d-66f6-466b-8a73-cb165dff0235',
#  '04f784ce-d314-4764-8018-37f385500088',
#  '0b163a4e-cc95-4aa4-b960-8ded32f664e6',
#  'd44a2f60-2188-4e70-b8e0-45adde8d3a81',
#  '0909eeed-61c3-4653-ad94-85ad627f69be',
#  '7759a6af-3793-4b5f-b57d-d8eb38c0398c',
#  '0b53e3b3-aa6f-4d67-8c99-1b54acec013e',
#  'c4cff4c6-1447-4122-b5c5-73d15b97781d',
#  '22faaecf-faf0-441f-8470-9341eaa2163f',
#  '607291c9-2bd3-4e36-8c7b-f057c5f667c8',
#  'f79cf7f3-18ad-4f16-86ee-afcc050bc07e',
#  'c529551e-a8d6-484b-b14e-cd532b93636f',
#  '684cbe3a-e4f1-4356-970f-3c15b021f72f',
#  '29a85047-478e-44b5-b424-8a5f1cb78e3a',
#  '8b2f551e-9f89-4963-804d-860ea05bb986',
#  '9e127032-e916-44e2-be48-8037636cba83',
#  'aac94b9e-a56f-453d-aa46-577e38fb5830',
#  '4ec7ebdc-533e-4f69-858e-f4ca96d4cc0f',
#  'a15e130c-839a-447d-98bb-70053697b63d',
#  '4773892d-7d93-4892-8f9d-d83cf5bf1b56',
#  'fbe90cc3-b1c3-4b91-9186-64cc31b1ba41',
#  '7e35281d-041f-4294-af29-c4981c212c33',
#  '3e6e68bb-196f-48c9-8ae7-06e2d95bb3ac',
#  '0d85a29b-4996-407a-85ca-2e910a3e7470',
#  '12d2779a-dca9-4ab5-a796-f75e09261910',
#  'dfb57526-9a60-4330-8bf4-9269962029ea',
#  '73d2c449-251f-4e24-8ace-0b44ca2c8f61',
#  'd43cd892-5bcb-4385-86ff-08cea83e500d',
#  '3a049219-3e9b-4f46-8a2f-6dfadc6683be',
#  '82a6f079-7520-4869-b077-469c47b711bc',
#  '8eed6c45-3898-421d-a5b2-eb300dbc6054',
#  '8d42a46d-f490-48c2-bfde-6c82c0934655',
#  'af445bdc-cd31-42ef-b4eb-693e66bc9afc',
#  '1d7d26ae-90a0-4a93-b6c5-29e42a6d0a34',
#  'c1eb9247-d3c3-45aa-99db-2803f38e3654',
#  '00e15af6-8d97-4122-ae61-c7c2e1dc5bad',
#  'eff9f1a2-ec30-4c80-a29f-bfd130a607d7',
#  '83d95e77-f69f-4179-a137-83f8652aaaec',
#  '0d52b550-14ae-4ef5-828e-b9ea4f03d49f',
#  'cfae4076-5719-460a-8a0a-7cae28f21840',
#  '1e9d2c14-7247-405b-a95e-7d61bf2acfb2',
#  'a138443f-2cee-4209-9065-63995a57b61a',
#  '78749d39-d302-47d7-8612-5b6ba12e076b',
#  '34bb8bb0-2244-47b4-b382-8660ba9f4df0',
#  'fd4da892-5254-4a32-88d5-641327c9e1d1',
#  '4d3d17b6-1898-4acb-9ba2-4c631e38063d',
#  'a5a11c89-0a6b-4108-bbc7-e9ec41270fba',
#  '5a7c18f5-5d02-486c-8d84-9550160c923e',
#  'eec6efe0-6e43-4a10-826f-5ca59f466cb0',
#  'f12de971-4a2b-48c7-b2d7-43c78a00088c',
#  'cd14d2a5-595b-417b-9c71-f641732d4fb1',
#  '0aa5e25e-9b85-418e-b334-a3fd3fba050b',
#  '19969d5a-6135-415d-8d56-88cc426effb3',
#  'a23b60ab-5d90-48e2-9aad-4a539d7276ff',
#  'cd333190-4506-4ba9-93bc-11ef6ca40a75',
#  'f8da9718-776f-4331-92d9-2d380dc4aa22',
#  '21d909e6-95e7-4625-be3d-11ccc2a9c62b',
#  'c07b6522-3e54-4573-a274-f0fca6146d04',
#  '00712bff-8e52-443e-b5dc-4da4a1cfd660',
#  '0f0722e2-cc91-47de-9e8d-c58a24b9fc4f',
#  'd5198214-e305-4c1d-9ac3-ca1917d4993f',
#  'f1f95ec6-0f23-4e00-94fe-b79698c6b1b3',
#  '5e80f6c2-0966-46bc-8dae-e9eb8feea4af',
#  '8054ed12-f5ff-42ee-9eb2-3847d7287610',
#  'd655b57f-db04-4732-b9de-14f494b63855',
#  '7ab5f437-c786-418b-953f-5b818b3e487c',
#  'd76101b6-2323-4736-9c4b-a90b65464a8f',
#  '32f0fd55-3e08-41ce-8536-cb9a5b220b0c',
#  '1afbec5f-20b4-4ee6-89a3-bb8fd67e597e',
#  'a88ab4b8-e1b8-4d06-af95-9710afb6ac04',
#  '068e5f92-7898-4e76-a837-137cd4af08db',
#  '1e95c71a-20b3-4e2f-9702-b2f11128786a',
#  '30569e95-0945-4180-bab0-ae5b0de32c81',
#  'baaf057b-beb6-4c34-91cd-0224a52193ad',
#  '141309fe-512a-43de-8aaa-276a7e7e0e25',
#  '18f7af40-6457-4a12-8540-571671ead3fb',
#  'f71e5696-4b8c-4b16-973d-81a724f6f08f',
#  '42d6d0ab-f79a-42e1-90e9-84147bb87713',
#  '77f0f4f4-ada4-42ad-8e5c-0b9f5cd3c2e6',
#  '0b712cc2-3c2a-4fb6-b96a-5e80460bfd45',
#  '2eaca77f-f0da-40b6-aa04-a45c5bb51642',
#  '7ee0bbe0-a98f-4068-8c30-0902de47d320',
#  'f4ca4df0-95e1-4707-9adb-9278ad6208e2',
#  '0f9bd387-85c2-4da5-ab31-ae6128669233',
#  'df77f47b-4b45-4c12-a900-53dc15fccf72',
#  'a950bbf3-423a-4438-8d6a-d66650dd260c',
#  'a1617bb2-9ca2-4eef-aa2c-aa74d8b169d0',
#  'b02d30cd-92af-4566-b60d-ce02a82cc201',
#  '1a7a83f3-95fa-4092-a086-60d7cdaf1c25',
#  '428e44fe-44dc-4ba9-af28-2e3938f2dd2c',
#  '4f37f4ab-6b93-4f7c-8fe0-6f490130e768',
#  'e5bad190-8196-4eb0-93d5-a150eb64aafd',
#  'aa6e7bb9-b599-490d-b314-cf639deb045b',
#  'b4926e14-b217-4f4f-8942-b686dc98adf4',
#  '77f453fc-05da-419b-8a2c-9586ff4e9745',
#  'a86cb8db-aa6c-4deb-964b-93e20966d7af',
#  '923c8ebe-1a37-470b-84ee-8ff821f601a0',
#  '5172b090-0e89-4c9c-98b2-b8f8eaafc6da',
#  '2a6ded3d-96c1-4480-8e71-80f60177035d',
#  'b1953794-ec09-4569-89e7-b205b667dde5',
#  '53a8fb57-26a7-467f-85d3-3054ef799277',
#  '4505ed21-5687-4d2a-8249-1ca89bb47ac8',
#  'd8dd5e93-f6e2-4880-ab41-dcc81790100c',
#  'b3cf78a0-c0ce-44ab-b019-c905c64d5c04',
#  '44b32d14-4892-4533-ae81-67894ea04601',
#  '171d4425-e9ad-4f3f-a9d5-aa6a3d7250ed',
#  '2f94cca3-a0e7-4c87-b498-25df259bd8c9',
#  'e2df9d96-5e39-4cba-b3dc-1c0a43f4ab9e',
#  '22d6b44f-112e-4558-8ed5-dd478f24cc6a',
#  '4072d5fc-a9bd-4f3d-b48d-7420aaca461c',
#  'e4fadd9e-6e5e-40d1-bc0f-b4995a394e37',
#  '5ff9b808-236a-4a3f-9c2e-9fffabe673a3',
#  'cd5aa36a-f80d-4784-9297-e74ee82b518e',
#  'b595e715-bf83-48b9-be8d-6f545bbd0587',
#  'ba276689-ac12-49b1-aa30-97442635e985',
#  'c49c9024-98bb-43af-b6fe-eaa3438ccb5c',
#  '07433e89-3b91-4c85-8a65-44e442dd7fec',
#  '5580c166-4513-4524-ae84-8ff3d08e329a',
#  '3f0048a6-1cf0-48c7-85ed-85aa22142521',
#  'e4f94d12-6ddf-4c9e-a8fa-fd83f1f98f46',
#  '1e80d2a5-56ce-44b5-8062-00ed7dafd3ed',
#  '21da9fc6-7662-4728-94ea-6d9126260a10',
#  'c2ed3cf7-f795-44cb-b661-82839ed00591',
#  '6e28110c-e991-487e-9681-5bff44980aed',
#  'ec181340-1708-4c06-ae08-2647e8bec8df',
#  '660fd877-220f-4a69-a0d5-afcb315f1ee6',
#  '42903069-6fe6-4c8e-a20f-9b4ed434750d',
#  'fa08a73e-b675-4964-b9b4-2998c3492bb7',
#  '964a4201-095e-434e-847f-8f8aaf849a0a',
#  '14dceda3-8edc-4f7f-a06b-92a256465247',
#  '7da3091a-cac4-4cde-8650-39a1d35a34b3',
#  'faedb9a5-d04d-406d-ac0e-3e162601f158',
#  '29b69768-9f49-43b1-8699-1cd4831bd4a2',
#  'f7b710b4-6c9d-4d20-b1a0-f9951f2b7e21',
#  'cf15c63b-f054-4ba0-a03b-07a40ad83a49',
#  'c9621fa4-c735-4c8f-8e14-b60d5bca7463',
#  '85e17828-63a0-4ccb-aef1-cb520bb2dcf4',
#  '4080bec2-3ebd-4a16-976d-8b179bbdfeaa',
#  '93eead30-ab8a-4cb0-bb7e-c2931fe88f78',
#  '103fd86e-0727-498b-a53e-781002e3bea6',
#  'b651336c-700b-4a28-8976-758a545089bc',
#  '14fd6b5b-f1ac-4ae2-8999-7429c2100485',
#  '0475315e-409b-430b-8ae4-0075c2e869cd',
#  'a1be04eb-b361-47be-92a5-656a45094150',
#  '267363ec-d23a-45d9-bf3a-42c5bcc0070b',
#  '4686c706-fc06-40a1-8402-7614cce23d60',
#  '7e41e1da-15bd-4378-92b6-61a0af7dfb97',
#  'b25e28a4-9a0c-4e49-8c12-7d5b971f9104',
#  '1c52684a-0302-4f4f-8cec-c58daf765197',
#  '4891607a-b43f-459c-93c9-4c8fae11e30b',
#  '02396c78-56b3-47bc-b19a-5a0c8393ceb3',
#  '9b4f700f-d929-4c4f-94d2-2ad058b5e13a',
#  'f8cc48c4-c136-4483-8c0e-951a8adde49f',
#  '6d862641-bdbf-4911-b351-7c0093fe054f',
#  'b467a844-8d43-48d4-b0a8-eae433ac7e82',
#  'c009cb9c-76bc-4a08-9a3e-7a009bb90f33',
#  'eb782aca-dc5f-4e26-ac95-402c6e5ae89d',
#  'e3197e6a-c5a2-49aa-8185-d6b785b69b43',
#  '6fe6fbf0-ec80-4897-9748-a651e14ef8ab',
#  '60771c4f-0041-4741-89b7-180464a92d4e',
#  '6b5293e3-1de3-4931-aac5-c3b2778be14c',
#  'c5cd2827-7011-4908-98c9-68fbace1f346',
#  '6263de78-88ab-484b-b235-c069f93416c8',
#  'aafdaa5c-5745-42fc-b1b4-38f7ababb343',
#  '0793f39d-8b80-4f3d-ba64-6efdde30042f',
#  'a474363c-b3de-4b2e-a7b6-996ee68d4e1f',
#  'a0b36c15-04b1-4612-950f-a0a0e5138888',
#  '81ff5a6a-acd7-46d1-9809-1e73e8255bdb',
#  'd171835a-9dac-4488-8a94-682ad7b7e3fe',
#  '1c43b74b-7f37-4e89-813d-7d4d7bf1aef9',
#  'fdaf8a55-bb31-4be9-80bd-5702f4a2d4ce',
#  '27c16644-fdf7-40d1-ad11-6119b1d58152',
#  '6206a01e-9191-4fe9-b00f-acf4455daa45',
#  '8f5b4643-614e-4e4e-9d36-fb69db8cd5d0',
#  '122080c1-0c71-4230-bf90-54a66667f78f',
#  '5ef5e1ef-297b-4abf-bb89-3f7a2832d490',
#  '4ffa5a49-2ccf-47e2-a320-8a80fb98f0df',
#  '84d5b226-6b1b-4d25-b7a3-c28d2fc78e78',
#  '86cd19f5-dfb3-4c9e-b392-72729a1af9d7',
#  'a0b9fe69-7533-4f3d-a0bc-5175e6b79051',
#  'e735e86e-d61c-4b11-aa17-053847216184',
#  'cc5c96c3-c43d-4b54-b47f-3e3f4699a4e8',
#  '737f4d63-caf7-4e91-947f-d6d5632c5168',
#  '6e8674e4-3687-4313-aca4-2b85ee2d120b',
#  '34f55616-e78f-4eed-a348-94c470f9cb5e',
#  '13f40f41-d547-4286-bad1-a6313769f412',
#  'd4dc2ea6-a6af-4cbf-b0ac-105265e784a7',
#  'db2e6c46-95dc-4ef5-8bbe-9a56e262bd0a',
#  '3e523b36-2016-4e02-a9e0-161c3ceba5be',
#  '6b437b77-b37e-4c5d-bf66-7233c04a0281',
#  'c60468c1-ad68-4ff1-a96c-a777dea24cae',
#  'e677a69e-714c-473b-b598-e82f06e6b6a9',
#  'a3e2383b-d871-4214-8a72-478748984d42',
#  '23b404ce-a882-45c8-9f44-40769ee2a2d7',
#  '28db5be4-4591-4ee6-9767-08d5a636317f',
#  '6cd48b14-80d1-4232-b1f4-67dbe65b8dd6',
#  '77eadf15-25e2-484f-b301-a96a23726c6b',
#  '6e200d3e-a391-4cd5-a359-1ee0c8f50353',
#  '3d9444f6-44df-4cba-8782-19f0b6529cf3',
#  '1a4a2d4d-e2b7-4dab-be59-ff116f29c54c',
#  'eaeba3e7-a8e5-4c33-a693-6ad900e5abd3',
#  'bde66aa9-b788-4bb7-9907-b8ab478d13ae',
#  '81fc49a2-f7bf-4baf-956e-6993a1f0008b',
#  '68dd59bd-8e8b-4286-90dc-c613feabe40f',
#  '3b5748e9-69e9-4190-8884-372d46579162',
#  '0582c818-2645-4944-bf37-8404a385409e',
#  '665eaaae-869f-4098-984d-8e4118ce19fa',
#  '9cdb5ea8-23b1-4a5c-aa1e-f1cbce1d2fe1',
#  'ce8a9c07-ef0e-4275-90e4-51358b7f9c3f',
#  '75dd536b-adb3-4048-b012-ab93e26349ef',
#  '55c32dc1-b8b3-4f07-a8d1-3225733c6e89',
#  '8c4c14cd-8cc2-4a4a-b5fb-502f9a4bc6b7',
#  '4d8b12b1-52a5-447d-850a-fd187cfa29bb',
#  'e95ab8e1-0c1c-4275-a329-491b32a9df61',
#  '8c3b6bf1-1141-48e3-b2b3-27161e0d124a',
#  'd7657a12-388a-43c9-9ae2-5c9fb5ae6382',
#  '1fb2869c-b6ef-492e-99e0-afb896145c97',
#  'e432814b-6528-4b10-a45b-844baad1ff68',
#  'e69af3ea-6c0e-4ee9-ba21-e7366d65d5c2',
#  '63b0824a-3fc7-4a16-8c6b-000c5a0b1584',
#  '14bda5e1-6ab8-422b-b908-34655f089aca',
#  '948a692e-4781-4d94-bf1e-ed92de60815b',
#  '1d9243ef-429f-4f5d-b67a-ad5f82b59b22',
#  '185f55b7-5465-40a6-964e-e0e508eb967b',
#  '889b5757-5577-4b6b-99c7-3d2f7508730b',
#  '87a672ce-845d-4b9c-b093-b4d2b2174dcd',
#  'b8484a54-20b6-4487-9211-82754e05bb8e',
#  '2064aa79-de30-4e25-b4ea-0a0c52a182d7',
#  '6cebb5b6-e59a-4c20-b9b3-5788ecbec29d',
#  '3bc843fb-6010-4d15-adaf-b47f600c1904',
#  '42475ca3-6d03-4310-966b-44150578f5f7',
#  'd64fc3e0-320a-4604-b9f4-41e39bc96cd1',
#  '67468841-8c96-4343-9635-2c8799693531',
#  '38215fad-927b-4f2b-8bdc-7460d40910f1',
#  '0bab3414-2ee7-412b-9dc6-69ab7a83ada6',
#  'ab666968-2dee-4cdf-bda0-1619cf5b5cd7',
#  'd4980beb-5023-4e23-8afa-a3c23fc3f029',
#  '40cbbe25-0f17-444a-8f0c-077263dfc4d1',
#  '29ef90ea-4e68-49c3-9f90-dd2755f671c8',
#  'ff5609fb-9c4b-4fb4-9305-9d615554fe5a',
#  '12f98615-b6da-411e-a02f-d6155e848193',
#  '6fb65a07-a8c0-4295-b712-875d5e674009',
#  '405c54eb-c31d-4c25-9703-616d000c65ad',
#  '7c748dc5-e822-47ca-8cf8-de59ebb39667',
#  '64770e98-12cf-48ea-92aa-f632e5b372e5',
#  '3ddda907-b225-476f-a45c-d36e6d01f4dc',
#  '6e936d66-c15a-4f63-9561-8e7d4a384d6b',
#  '3cb009ee-3d96-4274-9a11-3fd0fc93b67c',
#  'b8997766-5740-4055-a8b1-a130dd49e857',
#  '2cc3e92d-e9b6-4a14-ac72-d09b51cf9fd9',
#  'd2c97e5b-19d2-4a12-8553-bc71e1a2e8e3',
#  'f96f406f-85c2-49ac-b83d-54f2bbbecfac',
#  'ee37fd52-d069-4c0b-8468-56cad43399ca',
#  'f5409922-0514-4323-8069-da698826e60b',
#  '9b21f1d1-2828-4453-879d-f0044bd46c8e',
#  '419a54b1-5dd2-4c6d-97f2-088c5cf4febe',
#  '48f427fb-26f3-4f15-8e19-a7730aec21e2',
#  'ebca3f84-9fcf-4eaf-b0c4-8f21652d5c4e',
#  'bba2cfee-7034-4fa7-955f-604139acdd37',
#  'fee0af91-675b-49e2-8b74-a865426e3608',
#  '9aeba93d-18da-4c57-a4c4-a1c8918f3a3e',
#  '1fe94b41-bf7b-4cc8-9340-5b035939f29d',
#  '16055032-f66c-497b-bc81-bd208332cee3',
#  'ddfb1d2e-8132-4c05-ab2a-de8f3003ea7f',
#  '350ebc60-4930-4928-a54c-94e0652764bf',
#  '9fd31b4f-98c4-4710-85b6-b1ad653332dc',
#  '56e064e4-194c-41f7-8ae7-2659c837153c',
#  '5d0765aa-2d60-4cea-aea9-a39d739dfb51',
#  '1e5fe3ad-78a8-449a-858f-50cd9b676133',
#  '3d9e20ce-30b2-492d-911f-0be4721473c0',
#  'ef7cd848-a9a6-40c0-be97-aea19a0889f2',
#  '840c5211-7806-4a19-9287-063d6d928f4d',
#  'f81ac52e-4e46-4a54-beca-c50ee2ede788',
#  '2e1cb4af-c953-433b-a4fc-9a045d4cb58a',
#  '8424b721-e631-4130-8796-2b5c96c2edca',
#  'b21450f5-5589-43a8-baf9-cead1b1a85a7',
#  '69112f62-a319-47db-97f1-b009bcb106f1',
#  '2b3952d4-85c0-40fd-9df2-1ad03327bf72',
#  'e754296b-43c0-47d9-a484-d06d845a5468',
#  'd6337f58-a76a-4360-a290-0e2089afd3d9',
#  '362b9fb6-cf9e-4c42-b3e1-5e466082fb82',
#  'edb607f4-62a9-4f1d-b5c7-b3ce404bfb24',
#  '641a648c-08bd-4698-b308-014f32eaedba',
#  'e6d0edf0-1824-4bbf-bfd6-14b92702864c',
#  'cdb8f78c-39f9-49fd-a7a6-622b7972f83d',
#  'ec772303-211d-413f-8a78-339712490dbc',
#  'ee7c72f2-f5c1-4cb2-a76b-8facb29efe0c',
#  '7c82bcc0-64cb-4ff6-b601-6de99f82c38e',
#  'ea1906c4-996c-41b4-bf48-bc2886d1b357',
#  '3e03ad8d-48fd-4ffd-8f8c-3edec4268da6',
#  '49beb686-7bae-4ccf-a826-50c42899efb7',
#  '72ece883-f3ca-48b1-acc9-6da36a78ccb9',
#  'a8aaf875-7d2f-4a49-9bdf-ab0f67598f11',
#  'a5d04af4-6889-4d95-ae89-374888d2a4f0',
#  '21bc4a6d-2c91-4daf-aaa3-d10d8e7c61ef',
#  '0d2cc817-18ba-4e4b-a6fc-69dbf20e4b77',
#  '7108fcf6-4d10-405b-bd57-a59ca841bd86',
#  '933b3079-3546-419d-8e6b-438271764110',
#  '9b33a78d-5d02-4972-b9d7-5ac3a6f25ab6',
#  'ad225436-9dd4-44bc-940d-87a03a5f2526',
#  '24ae6daf-88d2-45bf-836f-28ebe7faf66f',
#  '81f90f2a-b922-4e2a-b4a4-4bc4f63ef660',
#  'e98b423a-f651-487b-8498-1e3ada2eca16',
#  '2ea517f6-1b27-4c14-9c81-32a8d3063dda',
#  'f19ecac2-3dc1-47fb-ad40-08ec7d270be9',
#  '4bb001de-0b7e-4fdc-a504-5173a42855da',
#  '08bc1659-564c-4d24-8c09-604a037c19be',
#  'baf4a516-159f-4f07-b027-fdf57cd832cc',
#  '8ad5d0a5-0f3b-4965-a617-13cf5174ea74',
#  '69947ca7-5e57-4a58-af79-c977e5ea8756',
#  'c63f9b88-0207-43ca-9184-fdac00b03aba',
#  '0ec21920-a839-4935-8419-480d88fb5b0e',
#  '24b1dd6a-b7e3-401d-a922-3c4567a92287',
#  '3d5f303a-f9c7-42c6-86a3-7d665b21516f',
#  'e43df550-4357-4498-8aad-6ac254d6e108',
#  '5b15a647-d140-4cbc-9572-409853606057',
#  'ed998617-fd8e-4dbf-a538-534a9cdee4a4',
#  '2a16c0f5-ebfd-41f4-a6bc-223f4410a382',
#  '85bab281-adcc-4ae5-897d-a55bb55057d7',
#  'd5a63429-fbcd-4ae4-9648-cfd14cb48e03',
#  '9471881b-1833-4d64-9dbb-a6fd7f86cb84',
#  '545a9e98-34d5-4954-af0e-c0a7707280e9',
#  'cb6b1511-67ab-48e9-8485-1b5860bcf094',
#  '786927ce-738e-45bc-bdf3-cb25f0c2736b',
#  '0a6fb3d2-75af-42ee-a0a2-e33a3485ced0',
#  'd0205b67-d5bd-422e-b789-b49c276ad9ee',
#  'c1601b2f-8fcd-4844-bcb6-378d525e21b2',
#  '6e29c30f-4b83-44f9-badc-83ff2bca267e',
#  'dd8a909f-8f80-41ac-88b2-8d978c82c980',
#  'ee71b881-a3d1-4d0a-9feb-de39b8f583b1',
#  'ff40b5d2-8a43-4500-9b2d-5f58d963eda8',
#  '97e3747e-034b-4b0c-92b7-2dd3b731bbb1',
#  'b427f9c6-8ef5-4434-97a9-e5c8abc4537a',
#  '227f35f8-f104-4a75-89b2-97bf05bb249e',
#  '5f8f4ae8-421d-422d-97ee-7f25a39f7297',
#  'b58eeae2-5fc0-466d-977f-c111403fcc14',
#  '68771bbc-ef09-478f-8f36-dbb319bc4c71',
#  '57d0a1cf-b0f5-4b62-8b5b-9c5b2e4eea17',
#  '6c985bc8-8b45-48fb-9b03-38863bfc1d02',
#  '60c86459-79ee-4c9a-98fd-458eef4f8c5f',
#  '100919fb-c729-4e0a-a670-16acadd0d7a7',
#  'ae8708e9-219e-4147-8418-dc5ab44c9a96',
#  '08e08864-7018-46f7-adcd-4f3c19cbfb85',
#  '5a0e2fb3-b8b4-43ba-8acc-d47d38639b99',
#  '144a5b42-8636-4224-b819-2713ec6cc17a',
#  '8d1e3f32-bcb2-4a46-ac1a-d083333c060c',
#  'c0729a20-ead9-4c7c-a3a7-0781e107cc72',
#  '1b5ea99b-3db6-4b48-b8e2-367c0de61058',
#  '38ce84a1-88ac-4e3b-aed7-091a8485b76e',
#  'f35160b1-1d6b-4a42-adb7-764d3ed73a36',
#  'a5dfafc9-a4d1-4929-9da5-3fd7fe4d0b55',
#  'c243d99d-8b5b-42e1-9130-7b6caa9271fe',
#  '5cec9f4f-d0d7-4290-a862-ad0d0985f55b',
#  '9b5d1b9b-42e5-4ddc-8611-3adbd2d954b7',
#  '66611b37-230a-43b1-b1fb-9f05bf10b254',
#  'eb94b18a-fdeb-469f-a1f8-a931de1ed0e5',
#  'b41e224b-121e-498d-8f2d-b15127d25749',
#  'b4f74585-411e-4821-8965-228351487ae3',
#  '656bf09e-32e7-4dbc-8b06-ee7aafc17084',
#  '71ba8456-af40-4c73-a0e4-84abdab757af',
#  'acff2f6d-7d24-4443-a40a-17256379bfc5',
#  'c3373fac-0a49-40eb-991c-0713a5dc37ea',
#  '9475b86e-bbd6-4137-acd4-6983546ccaa7',
#  '5fc3745b-ca45-4be4-99a9-b367e4146d8f',
#  '684ca7c6-5d8b-468a-a00b-d5250c85bf92',
#  '27bd37ce-1a83-4373-ba98-e46489c5a008',
#  '6d27f400-5cb9-4588-b580-6509763f7c8b',
#  '62d511ea-c517-489a-b0fb-126dc8caf1a3',
#  '6c3df1f8-3108-4bc2-8ee3-29e5f545b715',
#  'd5e957b2-50fc-4a6b-884c-d53966895c5e',
#  '3640badc-d367-4fc5-99a8-ad7e768fb2d9',
#  'fa5841f5-fb97-415d-8162-86990f714281',
#  '05a8f40b-79a3-448b-9e74-e61513ef7707',
#  'febed8fa-4fd9-467f-ba47-41aa198ba87f',
#  'a614b0aa-3758-42d1-be82-584401c37555',
#  '75bc955c-3ef8-41ff-9b5f-dc619899a322',
#  '610cf10f-c7da-4eae-93a2-9fbedaca5353',
#  '9857c130-3749-440e-ba38-b8f1859f506a',
#  '7c690ea8-2891-469c-a310-27aa3317e4e0',
#  'eb7765f2-a297-488f-962d-fde81dcc263a',
#  'edab25ff-523d-4f8f-8ea3-fe571db5a71b',
#  '828e83d6-52e0-494f-8e7c-63a6004ad45f',
#  'd5cca272-09f0-41dc-af67-6b35d0958c60',
#  '92a36b81-9121-4763-ae8d-96441b89e0b0',
#  'd58d5322-ed14-4ede-a6bb-5aa0768da324',
#  '5719e98c-0599-4a62-85a4-96c9b8409d00',
#  '8db982d2-ad3d-4a85-9787-655311dd73bf',
#  'a6e72360-90ab-4306-905d-cd124fe6f869',
#  '044f8fc4-3264-4dd7-98be-2c4a77523e39',
#  '7647a515-6e44-4cda-9a00-d3ffcc071f95',
#  'b0e5cc1f-14a1-4477-92c3-4ee535f1f5dc',
#  'a7a5d1f6-745a-4c35-b05e-b0c6b2beb6ee',
#  'cc4c8aaf-33fc-47d6-856d-ff20001e3d7f',
#  '45720632-6ef2-470a-b095-acbaa94a74fb',
#  '14e2aa2b-fc9a-48d6-b568-3e3d3548d329',
#  'a8a24e34-5dbc-4dc9-b9ce-0356c43b876c',
#  'bded490e-8716-4c64-b8b9-993878e1cb66',
#  '4cc79e44-570b-4dd8-8a83-70e5f1904c42',
#  'cad2e5cd-0135-4f1e-855b-0197964ec704',
#  'd95cba17-8c5f-41dd-8190-3ad47087771b',
#  '52522b14-4150-4a85-93b1-18a196911b43',
#  'e88841ea-8f47-4d79-9a4e-0c8fbc79807e',
#  '3423604c-e7d6-4cae-83a4-6821ec0feea4',
#  '388ab3e0-1657-4095-b738-13ad6e6cf82c',
#  'b6cbd4e2-521e-4fff-8c38-d48a6b636d73',
#  '04448f1c-95c1-48af-919c-f4b3d028681d',
#  '72572b89-7fa7-4d1e-aca9-e448c78a2a2d',
#  'c9b524a5-9165-43c4-a1f3-ed2e33befe19',
#  '609cf103-677c-417b-9e5c-97919506d595',
#  '0fbc0429-db7f-4954-904b-8d1cbc4081ef',
#  '13f94f07-6df3-4d58-ad23-7659d546b4bb',
#  'a3319a5c-10f8-4f55-ad4c-888d430cabfb',
#  '8890eb47-65f0-43ca-a7fe-ce5488e6cb9e',
#  'b12503be-c9dc-4821-9bf9-dba9b8c8b9e1',
#  '9cc11f10-d46e-4e0a-b8e1-8834686d7a15',
#  '7ee4dd0e-7c5a-4c46-9b70-03121d13bef9',
#  '738766ad-f7d2-4399-844d-81fbcd66da70',
#  '551c67b6-4c85-4913-919c-4e626adf6429',
#  '72e26687-99ca-42d9-8140-b0940ebe2762',
#  '883b6566-91fc-46e0-8cee-5e7c8bb8ed22',
#  '57be5413-c572-4665-be3a-36d73ab12fe0',
#  '39b09db4-ee22-41ac-9c38-9bdd0b4ea302',
#  'f21d8edd-febf-417a-a0a3-0779daf308f4',
#  '154f9c13-09e6-4d21-9b44-007b4b7fce17',
#  '93b6c147-733f-4b1f-8d62-766effef1c5b',
#  '4cb5bf84-d8f1-4224-aa1a-47cdf0e9e4cc',
#  'f02dbd47-210c-4ec0-9cf9-bcd42eeac7c4',
#  'cbcaa590-868e-4bf8-8774-6fb1f7f511d6',
#  '95ad1b32-aab4-4b45-b6da-befcef69c4c5',
#  '47fcba6c-064c-4ffa-8571-178fe8afbe35',
#  '38e2de17-2e30-442f-97ee-76b68764aa0e',
#  'aed11907-7402-4d2a-9935-c22a2a38468e',
#  '281f115f-9a29-4235-9622-0d657bc6135a',
#  '7070d734-a1d6-41ab-9828-83c753c82dad',
#  '6dafaee1-9104-4cd3-a318-d7c10e48874c',
#  'cd843a06-17cd-43e5-b38b-e981b6516711',
#  'cc5d4dce-6112-4ba2-8808-c37510dd4573',
#  '49150102-bc14-44d9-8f3d-4b3e083cdd5a',
#  '640b3efd-8a02-4c1f-b62a-a40fc62f12d1',
#  'f90329b1-faee-42f1-a8eb-b6d3ef161c08',
#  '9ecd4197-45d2-4801-b41c-9f6b4fe74b3e',
#  'b3cc2081-d570-4804-af25-ca99408e0151',
#  'fe7bec05-2c24-45d8-a64c-829676eba08b',
#  'c514d042-bec4-4d5e-82dc-f3002ce04e22',
#  '3bb9b76c-19e4-44ab-92e5-d8983c0a8473',
#  'b88d44bd-0fca-4636-8b40-8d6068c5ccdb',
#  'e981effa-73d2-4b00-bece-6a990f6f0dbd',
#  'ca7eb875-2098-4b57-9e88-e4af0b969ff0',
#  'de780604-b124-47c3-b05f-fbb082fc9855',
#  '6e7a916c-ab5d-496e-b199-05b0bcf0e113',
#  'b588e4de-13ac-4941-9c63-f9ecf7eae6b4',
#  '76313d37-b45e-4797-8227-2976a2cbb385',
#  'f53d8344-8c01-4ff9-826f-8b664fbd47f3',
#  'c945f6c7-8515-46a6-afbe-c554c63dd7fa',
#  'ae1bd45b-40a9-4f09-b4f1-7c0387da75d5',
#  '4fa1932c-367e-4dfa-9375-f576b4b4e0cd',
#  'e927232b-f1d8-477b-b146-d9f2d429ba0f',
#  '6cf1b0e0-1457-44a0-a746-b8861e55452b',
#  'd43aba33-a5e6-4edb-ba78-1580f964f794',
#  'dffb7582-66b1-4601-9890-d41f17f1ac47',
#  '079af5d1-6af3-453f-acf0-77db7a530207',
#  'ed292b7e-3426-4d0e-b277-82a20a886d6a',
#  '950b8b93-ee8c-4515-81e8-3aed04baa1e5',
#  'e35dbd69-d07a-411a-902f-f7c592b593ed',
#  '5e0203aa-9192-43e4-9bd5-e9fbb50dc965',
#  '2512a403-744e-4df1-ba21-6db6d1c103ec',
#  '6e38ccac-f040-4c20-9b90-fcd2bbfd26e2',
#  '6b6b1914-d558-4b97-80da-bdef9ed5fc8d',
#  '68215c27-b4f2-4c69-91ab-855240883459',
#  '6081a142-9a29-42a5-b8e6-7904877101a5',
#  '3331dfa1-76a5-4a78-b99d-8c2d24fd500b',
#  '9592fd72-bb76-4c0a-baca-d47641a5de28',
#  'dfbceff9-556f-4ca3-bb06-90a8f943997e',
#  'c793ffcf-b200-43b8-b5a4-ffedadef41cb',
#  '7681cb75-f898-4183-834f-b751f9f45544',
#  '90e38f9f-9cb5-4e06-a547-aca7f23e4ee5',
#  'ab580d96-5831-4d30-b262-a86161975ab3',
#  'f44f39a2-b5c7-45ec-98eb-dbfd90cde79b',
#  '0f234501-42d0-441d-9de5-1f4a59995494',
#  '51afa7eb-8535-4542-97a6-70178ecaf415',
#  'bdf2c6b2-dd11-4819-af2a-b8974409577a',
#  'e6cf2bb9-1f56-4c3b-8501-90c5fdf7967c',
#  '5135cb09-4416-4321-8783-c39a33f2c984',
#  'b53d17e2-18a2-4205-9ddd-0e89d09b2ee1',
#  'fe8c46d9-0054-47b7-a12e-cb0bcee8baa0',
#  '22781b2c-2716-4aef-a690-a8b2ddc56e12',
#  '37f17251-5405-433a-812f-dec42c4c2133',
#  'dd2085f0-5efb-4fba-8cb0-812a0a5004b4',
#  '20fb8a85-6f31-43a8-aa8f-90f63e2967f8',
#  'e842a25f-97cd-4f31-977a-45eb9098c6e0',
#  '4ea733a9-6dc5-4c55-bee3-f16df5b32181',
#  'c307d65f-a02e-429f-b65e-98fd9a7272aa',
#  '78b43afe-8409-4ff8-94ce-106a2a48d565',
#  '022b954c-75f1-411e-819f-7dd60d355651',
#  'bf595782-b57b-440c-b806-eb5d65f1a031',
#  'cc925e95-e818-435e-8259-811864883c8a',
#  'a239fb83-2a56-4a8b-b5bf-aa222710c4a0',
#  'ed1c8d53-7798-4f49-a925-9c5cd567dcf6',
#  '5661b5d5-0cd8-4756-855d-691e3c9cafa4',
#  '9a42e512-2d91-4c4c-91db-daf4320c72d8',
#  '96136b58-7f74-4341-80cc-756caaa35d13',
#  'b8223ac2-b355-41fa-8690-124c9c65fb29',
#  '0a14e8f7-f449-4573-9517-742de1fc0ef1',
#  '4aa25833-f92e-4a2a-8ecb-e8a8674d0f8f',
#  '22999952-574f-4af8-b679-d08208b9a8d7',
#  '794f2fb7-a0a7-4a0c-b174-42b235dbad92',
#  '594f850e-5f7e-4f3b-9dde-5e0bf8bb429e',
#  'ed6b5ecd-a6a8-4c4f-a7ef-50edb287b893',
#  '969ce9bf-7f83-41a8-9e24-40ea77940354',
#  'fc2f3603-7eaf-4400-8720-2168f2fe294a',
#  '431f329f-dbb6-46af-acdf-67b2a464782b',
#  'ebd6977f-ff85-4c1c-96f6-3384c00dc7aa',
#  'd1c15a6b-60c8-42c1-9fbd-645c8e1b43f5',
#  '33881759-b4a5-4b3d-bc05-4733c05a17f0',
#  '3c1fe6bc-b15f-497d-a7a4-3879ba027446',
#  '9c787de8-14a2-455d-b417-21d54d24e2bd',
#  '881ff5bb-f1d5-4e11-98b3-c8ddd2b25255',
#  'db9392bc-aa13-44f1-a578-41aea2698aaa',
#  '63169ab6-87c3-450a-b3ec-2eaf994f3a48',
#  'f2642b5c-e61e-4132-920a-cbe12e729d74',
#  'b0a59f30-856b-42a9-8db2-740cfcd576cb',
#  '87216e24-dbfa-41be-b51d-ec991aec0a92',
#  '6a67d81d-1c6b-4141-9e70-41a9d7e7823c',
#  '4b073adc-d461-44fe-b404-7729b2abf009',
#  '0aadecca-710d-4d8c-bfe5-ea5f5cb85876',
#  'd9217bef-c786-4228-8f8b-3f4a9838801a',
#  'ccfdeb37-c0e1-4cc1-9b96-9f84728ecc2e',
#  '35a4286c-b495-4fd9-828e-5b1062904f18',
#  '1a185b26-9938-49bc-b17a-131803ef8178',
#  'b5a91532-052d-467f-9875-567419861e91',
#  'b7953561-47be-4480-9bf6-b177cee422ff',
#  '3079e933-a8cd-446a-ae3d-f61b26d41548',
#  '678fd484-3f8a-4af9-933d-24ba73af5ddb',
#  '8a5b554c-177f-4fd5-81a2-4acdaee0223c',
#  '79b193cb-cc1c-4141-ab1d-3fe419646ebe',
#  '3a5507c9-d0c3-4d27-9b11-91f1371c86c3',
#  'bd57b757-a949-4a29-bd8a-71cfeb55ae75',
#  'cd685d31-a763-4633-ac49-3931641cf651',
#  '6d8effad-43ff-4e8e-a73a-bdc98d3a339b',
#  '27cfe32b-06d3-4b6d-96e7-a7ce7dcf8fc0',
#  'ee45597c-c668-42ca-a406-a5d8c420b344',
#  'c0ef6f01-9e7e-4dd9-9955-57e88cf90536',
#  'd94cd9ba-bd8c-4c59-82a1-5244e17811aa',
#  'b0518894-4782-4412-bc68-8bf7d8c7419e',
#  'da8b03d9-0a0d-4f2f-b36d-9f6d43a9fcfd',
#  '6268274f-1b0c-4c13-beb7-ac28e920f841',
#  '2d2d75fe-ea3a-4f4f-a42c-85c903ff5953',
#  'b5d22331-a5f6-4fc2-b4e9-0786836a6b3e',
#  '2dea9df0-aa5f-4847-943c-f7fd7c778104',
#  '7797d42f-1b99-4bc5-b522-3dae9999ef2a',
#  '6e60a087-fcac-4cf0-8960-461601fdda42',
#  'ec1ca183-1725-4407-a541-89c8885264fe',
#  '742c5e1b-592e-4243-b112-709c016fa4c9',
#  '908f6625-6141-4a3c-a965-89fb89b37e23',
#  '6b7fc038-524a-489c-9618-3e57a4425403',
#  'e817a37d-63f5-4510-9dda-65bcadafbf11',
#  '1bd42f68-24d7-4da2-b416-35801910c877',
#  'f1b5d988-fa56-4079-b897-3d67cef3e003',
#  '8a5fc9ac-8ba2-4952-87aa-09651958ed0a',
#  '75d28c53-5d4d-46c7-9b0d-8e8cf8b4d0e1',
#  'c48e617c-e859-4b0b-a858-43d0389651a4',
#  '0bac7283-ba4d-4905-80b2-81bd37e6798e',
#  '4b7c4b42-6e81-44a4-b114-68280802924a',
#  '1724d197-fa87-4897-bd49-30f1bb869c19',
#  'adef58cb-ac94-4994-9e78-b04235827955',
#  'ff3ad1b4-8dde-477c-a32d-795cc3a7b312',
#  '81dd4d6c-577f-4ed4-a879-13ef73c680d9',
#  'bdc9e4dc-2d20-4d57-916d-8b13837a53ea',
#  '1e6fb080-52c1-427c-a581-792a680ece19',
#  '97d388d4-aab9-4ca9-9124-66e357e99e87',
#  '214e9564-cae4-4635-ae8c-dda9d33b5fd7',
#  '97470e7b-b285-4199-a079-2f78ee54de94',
#  'c042caa4-719d-4926-b688-5f3170a56d2c',
#  '73e4d53b-1d85-41cd-89e9-940979b50ab5',
#  '4424d723-f8f3-407d-8968-fdd7cd55b4b6',
#  'c43a671f-93c1-4930-ae88-89f911042d52',
#  '34db6734-efa6-4821-ba64-10310acfd66a',
#  '4fa803ed-49be-4ce9-946c-86c9f46b3539',
#  'd46ad870-482c-41b4-8b13-dbc883ce6868',
#  '0af7874e-06ef-473a-bb5a-4c12f1f4e9cb',
#  'a118a2d5-b888-48e9-9b57-34ae80077598',
#  '9e485280-04a3-449b-8f70-89014c0ec940',
#  '28be62f4-0468-4a12-ac9d-4ce0d3b94c69',
#  'f0f5775d-2605-4473-bff9-1d0661fbb654',
#  '1e966da9-7dd9-4749-a8b6-97ddbb595afa',
#  'e045ab31-746f-4afa-ba33-c3d015941bc6',
#  '90ee8eb2-64a3-4be2-973d-c4ce77c2dd6e',
#  '1cf6db2a-4082-400f-a401-8020f9f14515',
#  '3bb74d38-9332-4c2a-8612-ec5bc2541596',
#  '12c0e2cf-7a05-4575-8403-d3f407a4a8e7',
#  '9d558284-c2eb-470d-943d-25ce2d973525',
#  'c616cd12-e8a3-4b46-ad8d-f53bf3a3e30c',
#  'e59b470e-ec74-457e-bd74-3073b2dc06d1',
#  'cd522aa5-95df-4714-ba7a-dc2ea462abfb',
#  '16407ed6-ceb0-499d-998e-87d3373f48ca',
#  'dcd95572-7744-4b05-9316-14e2b68df42c',
#  '0b103d71-5793-42dd-8550-cd715f8d7009',
#  'a9d3ea08-0454-4fb5-bedc-2a22bd464fe7',
#  '207a382f-9422-44c9-9329-4aefabc9d9a8',
#  '81be8ee3-bcec-4232-8658-2c8157308979',
#  '90d43535-788e-4894-9ae8-fe50273177ac',
#  '88aeec98-cedf-44f4-9efd-7c01d53aab73',
#  'ba33fefe-c1c4-4c59-a7a4-ae65de34719a',
#  'd997a374-e0bf-4794-8307-41d42f34a7e3',
#  'bdf5af5c-7cd8-4927-8f4b-ee10e56cdd00',
#  'b086d7f4-5dee-4a98-a8b4-3798e41f0601',
#  'f0990d71-dcea-4821-b314-a77523b0dcef',
#  'ac660eb0-9a1b-467a-86f6-5d5f8fa4b956',
#  '4f2ae1c5-578a-4d9a-8fc9-18914f69673f',
#  '8532213e-8189-4e62-9b27-5d8669061381',
#  '16c26c8e-1b64-4a09-b15e-384faafa6458',
#  '9508167e-f69a-4f52-b406-d0289f7c18a4',
#  '578abd53-3692-4543-b4c0-a0c7717c9415',
#  '908e59e7-abc6-4b7e-8377-89f5b0822231',
#  '30ce5b68-a662-4a9a-8255-c847ca0c62d5',
#  '5c4da0da-bd46-46e2-97b9-ffc8a62efb64',
#  '5ed54c8f-2f6a-45d7-8ab1-10b1ee424bb1',
#  '638c4ac6-12ae-475e-acf3-1395f9f12d8c',
#  '80f43ebc-82ac-4fc5-bb46-14b4c435a64c',
#  '8fe66908-6634-4064-995e-5075a6deaf05',
#  '8b03a467-6ccc-44de-8c74-f801167f9ec1',
#  '98bc7804-3439-4c63-a1fb-ef26a27826a3',
#  '54d2a4e3-b611-48c1-891a-c82f5893a3e6',
#  '6fb3e423-1bb9-4387-b9c1-31249c2ba451',
#  '33d75355-1cd0-4afe-9e8d-2a5ea0c07adc',
#  '68ad2640-f52b-4632-ba30-c3f4b05d706e',
#  '4df5dbb2-4a8e-4db3-b428-450d4d88fe19',
#  '0e846734-15e7-4336-9a02-6241c01d82fa',
#  '1a45df7e-4ff1-4fa7-9ed8-802989a680f3',
#  'b0b3fd6c-e6e6-4fc5-babd-020a06c45050',
#  '33f73b38-9ebb-4182-80a9-e1543d34c8f1',
#  '87e3c468-3d8f-4533-aac0-e2b726b39b0e',
#  'c2c7fde3-726c-452e-a8cf-acb754b60a91',
#  'a8eb9df4-b4b7-4e00-af69-f3fc7ce2cc4f',
#  '5f65be47-cee1-466e-b8f4-e43e2883b3db',
#  'cc1cc306-0e40-4e8f-b339-ef19546bde15',
#  '70466b47-cd63-4b66-b065-2d18aad29d55',
#  '2a7e5634-bd5a-4fa1-9f05-6ff841fa671b',
#  '8e93354c-d259-4ff8-8e03-5f76591345f1',
#  '1214e1e2-8619-4654-a3ca-8e7391f06144',
#  '4f6438ad-c2c7-49c0-9538-44f01fb41867',
#  '65cc7707-0a28-4354-8dda-3ab5dfb9becd',
#  'cd6116c5-c3f6-4d15-9378-f2f34e0d0e23',
#  '2229c512-f630-4ae8-8067-53c7779a6e82',
#  'b36cd7db-d163-4cf5-8acb-baf78c84abf1',
#  '73568f91-41ec-4783-b203-8d4e040afa1f',
#  '6f8fc98f-ca06-4a7c-88a9-bbea68548078',
#  '78c57b63-71f1-412a-b00a-8583038d4354',
#  '09bb132f-af6c-4265-8ea4-2737f9ac3b20',
#  'a57b02fc-7597-42b9-be7e-cc42cfc2b7b5',
#  'db7a1507-d980-4b26-8c3f-7ac3cb0a0f1b',
#  'cf04f46b-ab1a-4522-b830-63b28fd38fdf',
#  '5c0ecd2f-7b29-42e8-817f-3aef01ff45eb',
#  'db6139b1-6131-456c-bdef-faa564cdc67e',
#  '0bbdf588-51ad-4ff8-8201-5b8921c1985b',
#  '21bd4b2e-f25e-4cd2-8dd7-f3b1cbc5fa7b',
#  'ef70600e-fa46-400e-8e51-face1c34de6e',
#  '0c07fbb6-bf01-454b-b3cc-d1f4fe3957a2',
#  'ed6d5049-f61b-40ad-9ba1-cb51b19d4016',
#  '56a2f293-0c74-4d3f-b571-6ba79c257c4d',
#  '944fc0d7-323f-48cf-8180-777b000d464a',
#  'af736267-60f1-4473-bf1f-065b36753c13',
#  'db8c0110-bbdc-4b19-9863-78aa80e00309',
#  'c9480ef3-cc00-429c-9a24-74a282aed705',
#  '06beaf53-51e5-48b3-894d-0b58b4050272',
#  'ca3ac5b2-34f8-4c7e-a7b0-64568874e6b1',
#  '5a18593c-53e8-4917-8514-649ad079bbc4',
#  '8e7867b3-9b3d-40d0-9d35-69cb69d6371f',
#  'fd230381-dece-4d64-9d78-3af9e886cc99',
#  'ed1a4fae-5038-4a0b-bfa0-5e6ace5d7fc4',
#  '7b80cc7e-f167-428d-8426-981d3a38f0a6',
#  '5b059a90-377a-457f-a9d5-0cc8cc4b40de',
#  '5bf5bb7e-4d0c-4ec4-a609-09c1711076a8',
#  '82cb5b7c-88ff-4e3d-bff4-10d2a75eafb6',
#  '37e8ad3c-b2a7-4f15-ab9b-c6a8b019b390',
#  '884bf4f5-c957-4c35-96d0-f03539d32398',
#  '3602c05b-4ac3-4194-9f23-0d9b9ee3d6a5',
#  'f58c2f2f-1679-4bf0-9c8a-472bb6b07a11',
#  '94de283e-210d-43c8-9d6b-d52cde88b2c3',
#  '125d5035-7240-4f1b-8fbd-c50dd8388760',
#  'ead7e387-ea8f-466c-afd4-2b761f3860c6',
#  'bf9319ee-137c-4adc-831d-fb2765b27dbc',
#  'a755aa51-6bb9-474a-8fe0-3527b9bc1ab0',
#  '9d994d15-4401-4f46-88b9-1bc33fd771d1',
#  'd5396fdc-1e58-46ad-8856-574bd3d887f8',
#  '278d129a-f90b-4427-a39a-8e2686ca1199',
#  '3d28f38f-5c15-459b-abfb-9c4f6882bfc0',
#  '4b9f4fd5-d7b6-4578-ae70-610a26d9c976',
#  'e4db445a-8b9f-4a97-8366-f81c78ec4887',
#  '83f64d3c-2638-4635-98a6-ada57e76455f',
#  '8fe18888-3fe1-4c35-8513-b5e0d9bb6464',
#  '62d6f1f2-e4c4-4a99-b72e-9b2047f840ba',
#  '6e0904c4-aa76-44e9-a124-8cc8744d1766',
#  '9f96a736-83a9-4d5d-b27c-146d616ee6a5',
#  '95836cc5-c85d-4524-8e63-d3bb90adcdbe',
#  '69210885-6de5-492f-8c5c-52b1aabc7a2f',
#  '5b78204b-1f27-4a65-8bd1-b7930c936540',
#  'f5693a98-9169-41a7-bdb5-2571de8e63ef',
#  'e9254d44-80a1-41dd-bfdb-7160d7d504f1',
#  'bc641045-223b-4acb-9c78-f18819f2fe39',
#  'a69aed6a-3f02-4efc-83a6-b3345460fbaf',
#  '8ad13fbb-af65-4d90-9502-3df5a4ae9aa0',
#  '7c29f67b-9112-4dcb-bace-e2ff92244825',
#  'f2f6dc06-53cc-4f76-b3ae-7658bdbe39a8',
#  '746cbc0c-c588-4913-87bf-df8c00274396',
#  'ecd5f597-55dd-4fbe-a934-05e0ce3b660a',
#  '8586b0ac-f9b5-4144-8dc3-e7bc3018ed74',
#  'c3cef631-84c5-48ed-9859-cada6862946d',
#  'b1b73fa0-e2bc-4948-a2bd-75ff9afab402',
#  'd785b9b4-f2aa-4615-bd7b-577d5583d1ff',
#  '8a614d88-a7cd-4e27-883f-1e5626b173fd',
#  'fa66fa00-129f-4edd-a476-c46d95e079f3',
#  '3caa6e00-2a42-4d11-9c7d-7cb9f4e7ca98',
#  '70e6354e-76f4-4143-9019-d32434ecf650',
#  '52a39403-7904-4fcd-ac23-073e9d2f11d2',
#  '3c4ad617-bb41-458c-9f27-93631a4de4ba',
#  'efd90804-ee3a-44e2-ad89-7b667a2dcb64',
#  '267d52b6-8fe4-4fde-a095-c827f1432972',
#  '303b23e7-3c5c-427b-a1a9-3068149a4fe9',
#  '058c2052-80d7-4fe3-b473-e2543441b64a',
#  'e8933438-a593-4216-9d77-6aea8ce7683a',
#  '881e7bb7-5cd5-46b4-b066-bf92f2794ecf',
#  'a841ca11-84cc-433b-98a3-b0fbf950d851',
#  'e6997046-da5b-49c9-a1eb-ba18110eba19',
#  'cdf0277c-50fd-4d75-8074-c98ddd7b97c6',
#  '6b050828-143e-4cd9-886a-08fa34deeb7f',
#  'fd034620-8516-4c29-9bb6-72d11797ff5b',
#  '4e21da56-7793-4fd6-a696-0e59e0cfa521',
#  '50538f6c-8fba-47a5-8aa4-84a108d6c323',
#  'f2888777-a0c1-4fec-bd80-f1fc3c02ae77',
#  '057275ab-8d54-4218-a1db-208d1b2ebf90',
#  'b23283e5-e8c5-490b-bb65-6b59c8f64ae3',
#  'e375bc70-fb8e-4aa6-b570-7b9a1629e4e4',
#  '631b3913-a4ff-4b70-9a06-47a4186d1186',
#  '54a2ec4f-f3a7-4064-a37c-c1085ec64143',
#  '1b622805-6d01-48c0-83b6-c3b7ae9d6e86',
#  'ce298afb-0b51-47df-bc86-bf170a1e2660',
#  'f379823a-f230-4041-b00d-6092c7d74f67',
#  '72a00674-83d0-415d-b785-c630188fdb56',
#  '10b685ff-8afa-42d9-bc75-14ab7d95daa3',
#  'fae55a55-71e5-4b7f-9f9a-5c192b57bc4d',
#  '44e9f91e-2764-4788-bd7b-186a693ba5fc',
#  '10524cfd-3354-4a74-bbf1-519d6155872a',
#  '329ffe46-16f1-4aab-8114-938814d57a58',
#  '9850a8d1-bf23-4249-8797-c67da4f90d79',
#  'f6edc399-d928-4f84-bde3-37bb478aefe6',
#  '53391773-ff92-4b0e-add7-a1aa8feed6b6',
#  '65a9e131-ac07-4295-afb0-6bc8751c34e9',
#  '5bdb78d8-2962-470d-9025-b0efa8cf7ffc',
#  '83960fbc-12c6-4e9a-9043-4138692c87ba',
#  '4f80db04-d11c-4f34-a04f-a5483f20a099',
#  'e8e1d39b-a81f-485f-99cf-0177b46cab0c',
#  '97fd0324-cb75-4843-9520-03212ba6201f',
#  'c2b282aa-ee6a-4d9f-ba06-aa9277554c1e',
#  '3f59b1b1-c6c3-44c3-9547-0d0b1105f718',
#  'cb077a61-738f-47a9-90e7-4ee53d81b296',
#  '937a6937-a248-4fae-903c-ea3f572a0ca2',
#  '621e2eee-a064-45af-82a0-2996fabe01c4',
#  '426c64a5-1c7b-4267-8b3f-c187043ec899',
#  '1e62cd37-d548-40e2-8bfc-43865db9bbf1',
#  'f79dab7a-3cf5-4ff9-b32d-3c0df7218885',
#  'a6f25571-0c81-400b-a68a-3980e81cf2a3',
#  '6ece2120-40ec-4773-91d0-c0b5a9508663',
#  '134632c8-6380-482b-af03-78b6120dcd1f',
#  '93eb9f73-6301-422d-9c40-87b324445daf',
#  'bd4571d9-ea7d-4089-aeab-5805fda452de',
#  '3b62b33a-f1c8-44a4-b2dd-c9d25b66f727',
#  '4aefea8c-545c-4a2b-baf7-1817c1b5e7fb',
#  'a9901117-6ea7-4f30-a5bc-15ef1fb02c25',
#  '679b0a6d-1b41-4e5c-9d38-830c69d985f8',
#  'bae41b74-7b83-4bc5-bc02-276e693e2727',
#  'abc3b44f-b705-480c-a0e4-26a2d9108138',
#  '5801cdfa-696b-40b5-a5fb-4e714c05aa2d',
#  '857786ac-d1bb-47af-87df-06aa77b68a24',
#  'c3d5fa62-f5a7-499e-bc3e-dc78b5753c89',
#  '9f075903-514b-4576-8383-a65f8e8ea093',
#  '461921a6-c37c-4139-8fe1-3570a5934702',
#  'e5b36d0c-5f27-4463-9318-e584d99e37fb',
#  '461bfe69-4d99-40fd-915e-e5eb0b7d35c8',
#  '65a3d1a3-35b2-45dc-9ab6-58b35faac7c9',
#  '59fdb518-c7bd-468d-8f15-27d2d84969d5',
#  '6d02e36a-ff0b-45ea-b0de-1375658f25ca',
#  'e99c2090-677e-4185-b7e6-f35b2fe7b9be',
#  '16311bfb-c3b1-4e12-aad2-85dd7774013a',
#  'b7cebd1b-9076-4353-b5d6-f6a70864224b',
#  '157bde04-3eb4-4c72-89a7-2b2d1f404aca',
#  '074f00b9-d208-4da0-9c0e-ab53f4ce5432',
#  'cc6a9e8d-4050-47df-90cd-225d354cb505',
#  ...]

# %% [markdown]
# ### **Setting up the ChromaDB Database and creating a collection for to store the embeddings**

# %% [markdown]
# **This below code snippet initializes a ChromaDB collection named `'subtitle_multi-qa-MiniLM-L6-cos-v1_bert_embeddings_final'` with specified metadata settings. The collection uses cosine similarity for embedding space. The purpose of this collection is likely to store and manage embeddings related to subtitle data. 📊🔍**

# %%
import chromadb
from chromadb.config import Settings

CHROMA_DATA_PATH = 'subtitle_chromadb_data/'

# Create a collection named 'subtitle_bert_embeddings'
client = chromadb.PersistentClient(path=CHROMA_DATA_PATH)
collection = client.get_or_create_collection(
        name="subtitle_multi-qa-MiniLM-L6-cos-v1_bert_embeddings_final",
        metadata={"hnsw:space": "cosine"},
        embedding_function=None
)

# %% [markdown]
# **This below code snippet adds subtitle documents and their BERT embeddings to the `subtitle_multi-qa-MiniLM-L6-cos-v1_bert_embeddings_final` ChromaDB collection, along with associated metadata that we created before. 📊🔑**

# %%
document_ids = [str(id) for id in df_sampled['cleaned_content'].index.tolist()]
subtitle_embeddings_bert_list = subtitle_embeddings_bert.tolist()

collection.add(
    ids = ids,
    documents = df_sampled['cleaned_content'].tolist(),
    embeddings = subtitle_embeddings_bert_list, 
    metadatas=metadatas
)

# %% [markdown]
# # **Part 2: Retrieving Documents**

# %% [markdown]
# These below `preprocess_text` function and `search_query` function performs a document retrieval process based on user search queries:
# 1. **Preprocessing**: It cleans and preprocesses the user's query by removing timestamps, line numbers, HTML tags, special characters, and stopwords.
# 2. **Embedding Creation**: It generates a query embedding using sentence embeddings (e.g., BERT).
# 3. **Cosine Similarity**: The code calculates cosine similarity scores between the query embedding and document embeddings.
# 4. **Candidate Selection**: The most relevant documents are returned based on these similarity scores.
#
# In summary, this code enables efficient document retrieval using semantic search techniques. 📄🔍

# %%
import re
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

def preprocess_text(text):
    # Remove timestamps
    text = re.sub(r'\d+:\d+:\d+,\d+ --> \d+:\d+:\d+,\d+', '', text)
    # Remove line numbers and HTML tags
    text = re.sub(r'\b\d+\b', '', text)
    text = BeautifulSoup(text, "html.parser").get_text(separator=" ")
    # Remove special characters, punctuation, and symbols
    text = re.sub(r'[^\w\s]', '', text)
    # Remove extra whitespace and convert to lowercase
    text = re.sub(r'\s+', ' ', text).lower()
    # Tokenize the text and remove stopwords
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    # Reconstruct the cleaned text
    cleaned_text = ' '.join(tokens)
    return cleaned_text

def search_query(query):
    # Preprocess the query
    preprocessed_query = preprocess_text(query)

    query_embedding = generate_sentence_embeddings([preprocessed_query])[0]

    population = collection.query(
        query_embeddings=query_embedding.tolist(),
        n_results=2
    )
    return population

# %%
search_query('Hello!')
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'ids': [['a90ae7f4-ca61-4e93-b0de-56dcfeeadbad',
#    'c7bfc675-c3c3-41c8-b629-8714d9fdecc9']],
#  'distances': [[0.4949023723602295, 0.5080372095108032]],
#  'metadatas': [[{'index': 22945, 'name': 'chakravyuha.(2016).eng.1cd'},
#    {'index': 6194, 'name': 'salam.(2018).eng.1cd'}]],
#  'embeddings': None,
#  'documents': [['ï bye bye watch video online opensubtitles free browser extension osdblinkext papa way us day come touch feet wont get key mom bless dear bubbling impatient accept loved say yes pray dont fall love someone else want promise love alone keep away others even dreams thats okay hello think happened come dream girl doesnt suit sorry okay loose okay bye dear bye bye come home quickly dont ask reason come home quickly please please come quickly please please come quickly love obsession near peace hi yes slave learnt make coffee wanted taste made thats please come pray god dont belong someone else nuisance dont want anything else even dream keep away others dont mind use phone yes sure hello know happened yes yes okay okay thank cute love bubbling impatient hello hello one moment sorry relationship girlfriend nothing kept phone engage hour receiving phone sorry mistake kept girlfriend engaged hour keep girlfriend engage hour okay hey hey hey leave mad crazy sorry sorry mistake day asked address construction site oh dont remember called item mistake sorry item yes hey mad senseless call anyone item mad go check go go hey hit made certificate physically fit go prison watch video online opensubtitles free browser extension osdblinkext',
#    'advertise product brand contact wwwopensubtitlesorg today hit come help hit dont want way whats going visitor mouse mouse see see stop rashad im helping bravo thank yeah hit like enough im going catch go hit hit hit come hit kill couldnt going run away thank god thank salam take away always scared boy wasnt scared didnt want way see hamad stop ill take outside come love hey little mousie another bombing hour ago heard anyone yet internet phones still always takes time close eyes look wear school next week say thank aunt thank youre welcome go show father think theyll stop bullying getting late get going call hear anything may god thank oh hey rashad hi salam heard father mother fine thank god salam musa hospital salam hear yes head injury hes surgery serious still yes come home dont worry money hello salam go audrey yeah drive dont know drive dont address far please hey know places city women need help yeah im fine thanks dont seem fine youre oppressed doesnt mean need coffee im sorry said inappropriate yes bronx originally bronx okay im palestinian ive never allowed go back born syria oh upstate little town called kerhonkson know really yeah pretty mom still lives mean havent back couple years shes complicated husband mother dont really get along boyfriend husband really whats name musa hes nurse kids complicated wanted wait hes hes think could drive upstate pull okay didnt yes okay go back hello hello darling apiopensubtitlesorg deprecated please implement rest api opensubtitlescom']],
#  'uris': None,
#  'data': None}
